# %% [markdown]
# # WikiArt Style Classification — Test 7 (Higher Than Test 6)
#
# This notebook runs a stronger long-training setup than Test 6.
#
# ### What is stronger in Test 7
# - Longer fine-tuning schedule
# - Stronger regularization (MixUp/CutMix)
# - Slightly stronger EMA
# - Safer eval split logic (fixes the `label` split issue)
# - Separate output files so Test 6 is not overwritten

# %%
import copy
import math
import os
import random
from dataclasses import dataclass, asdict
from datetime import datetime, timezone
from pathlib import Path
from typing import Dict, List, Optional, Tuple

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from PIL import Image
from torch.utils.data import DataLoader, Dataset, WeightedRandomSampler
from torchvision import transforms

try:
    import timm
except ImportError as exc:
    raise ImportError("This notebook requires timm. Install with: pip install timm") from exc


@dataclass
class TrainConfig:
    model_name: str = "vit_base_patch16_384.augreg_in21k_ft_in1k"
    image_size: int = 384
    batch_size: int = 10
    effective_batch_size: int = 60
    head_epochs: int = 4
    ft_epochs: int = 40
    patience: int = 12
    warmup_epochs: int = 3
    head_lr: float = 5e-4
    ft_backbone_lr: float = 5e-6
    ft_head_lr: float = 2e-5
    weight_decay: float = 1e-4
    mixup_alpha: float = 0.6
    cutmix_alpha: float = 1.0
    mix_probability: float = 0.9
    label_smoothing: float = 0.08
    ema_decay: float = 0.9998
    grad_clip_norm: float = 1.0
    tta: bool = True
    use_weighted_sampler: bool = True
    seed: int = 42
    num_workers: int = 0
    progress_every: int = 120
    fast_mode: bool = False


class WikiArtStyleDataset(Dataset):
    def __init__(self, rows: pd.DataFrame, image_root: Path, transform=None):
        self.rows = rows.reset_index(drop=True).copy()
        self.image_root = Path(image_root)
        self.transform = transform

    def __len__(self) -> int:
        return len(self.rows)

    def __getitem__(self, idx: int):
        row = self.rows.iloc[idx]
        image_path = self.image_root / row["relative_path"]
        label = int(row["label"])
        image = Image.open(image_path).convert("RGB")
        if self.transform is not None:
            image = self.transform(image)
        return image, label


class ModelEMA:
    def __init__(self, model: nn.Module, decay: float = 0.9997):
        self.decay = decay
        self.ema_model = copy.deepcopy(model).eval()
        for p in self.ema_model.parameters():
            p.requires_grad = False

    @torch.no_grad()
    def update(self, model: nn.Module):
        msd = model.state_dict()
        for k, v in self.ema_model.state_dict().items():
            if k in msd:
                model_v = msd[k].detach()
                if torch.is_floating_point(v):
                    v.mul_(self.decay).add_(model_v, alpha=1.0 - self.decay)
                else:
                    v.copy_(model_v)


class SoftTargetCrossEntropyWithLabelSmoothing(nn.Module):
    def __init__(self, smoothing: float = 0.0):
        super().__init__()
        self.smoothing = smoothing

    def forward(self, logits: torch.Tensor, targets: torch.Tensor) -> torch.Tensor:
        n_classes = logits.size(1)
        if targets.dim() == 1:
            with torch.no_grad():
                true_dist = torch.zeros_like(logits)
                true_dist.fill_(self.smoothing / (n_classes - 1))
                true_dist.scatter_(1, targets.unsqueeze(1), 1.0 - self.smoothing)
            targets = true_dist
        log_probs = torch.log_softmax(logits, dim=1)
        return torch.mean(torch.sum(-targets * log_probs, dim=1))


def set_seed(seed: int):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def discover_paths(project_root: Path) -> Tuple[Path, Path, Path]:
    wikiart_dir = project_root / "datasets" / "Wikiart"
    train_csv = wikiart_dir / "style_train.csv"
    val_csv = wikiart_dir / "style_val.csv"
    if not train_csv.exists() or not val_csv.exists():
        raise FileNotFoundError("Could not find style_train.csv and style_val.csv in datasets/Wikiart")
    return wikiart_dir, train_csv, val_csv


def load_style_csv(path: Path) -> pd.DataFrame:
    df = pd.read_csv(path, header=None, names=["relative_path", "label"])
    df["label"] = df["label"].astype(int)
    return df


def make_eval_split(val_df: pd.DataFrame, seed: int) -> Tuple[pd.DataFrame, pd.DataFrame]:
    sampled_parts = []
    for _, grp in val_df.groupby("label", sort=False):
        if len(grp) > 1:
            sampled_parts.append(grp.sample(frac=0.5, random_state=seed))
        else:
            sampled_parts.append(grp)

    eval_test = pd.concat(sampled_parts, axis=0)
    eval_val = val_df.drop(index=eval_test.index)

    if len(eval_val) == 0:
        eval_val = val_df.sample(frac=0.5, random_state=seed)
        eval_test = val_df.drop(index=eval_val.index)

    eval_test = eval_test[["relative_path", "label"]].reset_index(drop=True)
    eval_val = eval_val[["relative_path", "label"]].reset_index(drop=True)
    return eval_val, eval_test


def filter_existing_rows(df: pd.DataFrame, image_root: Path, split_name: str) -> pd.DataFrame:
    keep_mask = df["relative_path"].map(lambda p: (image_root / p).exists())
    missing_count = int((~keep_mask).sum())
    if missing_count > 0:
        print(f"[{split_name}] Filtered out {missing_count} missing files.")
    return df.loc[keep_mask].reset_index(drop=True)


def build_transforms(image_size: int):
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    train_tfms = transforms.Compose([
        transforms.RandomResizedCrop(image_size, scale=(0.55, 1.0), ratio=(0.75, 1.33)),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandAugment(num_ops=2, magnitude=11),
        transforms.ColorJitter(brightness=0.15, contrast=0.15, saturation=0.15, hue=0.04),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std),
        transforms.RandomErasing(p=0.22, scale=(0.02, 0.18), ratio=(0.3, 3.3), value="random"),
    ])
    eval_tfms = transforms.Compose([
        transforms.Resize(int(image_size * 1.14)),
        transforms.CenterCrop(image_size),
        transforms.ToTensor(),
        transforms.Normalize(mean=mean, std=std),
    ])
    return train_tfms, eval_tfms


def create_weighted_sampler(labels: np.ndarray) -> WeightedRandomSampler:
    class_counts = np.bincount(labels)
    class_weights = 1.0 / np.maximum(class_counts, 1)
    sample_weights = class_weights[labels]
    sample_weights = np.sqrt(sample_weights)
    sample_weights = sample_weights / sample_weights.mean()
    return WeightedRandomSampler(
        weights=torch.as_tensor(sample_weights, dtype=torch.double),
        num_samples=len(sample_weights),
        replacement=True,
    )


def mixup_cutmix(
    inputs: torch.Tensor,
    targets: torch.Tensor,
    alpha_mixup: float,
    alpha_cutmix: float,
    p: float,
    num_classes: int,
) -> Tuple[torch.Tensor, torch.Tensor]:
    if np.random.rand() > p:
        return inputs, torch.nn.functional.one_hot(targets, num_classes=num_classes).float()

    batch_size = inputs.size(0)
    indices = torch.randperm(batch_size, device=inputs.device)
    targets_onehot = torch.nn.functional.one_hot(targets, num_classes=num_classes).float()
    shuffled_targets = targets_onehot[indices]

    use_cutmix = alpha_cutmix > 0 and np.random.rand() < 0.5
    if use_cutmix:
        lam = np.random.beta(alpha_cutmix, alpha_cutmix)
        h, w = inputs.size(2), inputs.size(3)
        cut_rat = np.sqrt(1.0 - lam)
        cut_w = int(w * cut_rat)
        cut_h = int(h * cut_rat)

        cx = np.random.randint(w)
        cy = np.random.randint(h)

        x1 = np.clip(cx - cut_w // 2, 0, w)
        x2 = np.clip(cx + cut_w // 2, 0, w)
        y1 = np.clip(cy - cut_h // 2, 0, h)
        y2 = np.clip(cy + cut_h // 2, 0, h)

        mixed = inputs.clone()
        mixed[:, :, y1:y2, x1:x2] = inputs[indices, :, y1:y2, x1:x2]
        lam_adjusted = 1.0 - ((x2 - x1) * (y2 - y1) / (w * h))
        soft_targets = targets_onehot * lam_adjusted + shuffled_targets * (1.0 - lam_adjusted)
        return mixed, soft_targets

    if alpha_mixup <= 0:
        return inputs, targets_onehot

    lam = np.random.beta(alpha_mixup, alpha_mixup)
    mixed = lam * inputs + (1.0 - lam) * inputs[indices]
    soft_targets = lam * targets_onehot + (1.0 - lam) * shuffled_targets
    return mixed, soft_targets


def topk_accuracy(logits: torch.Tensor, targets: torch.Tensor, topk=(1, 5)) -> List[torch.Tensor]:
    with torch.no_grad():
        maxk = max(topk)
        _, pred = logits.topk(maxk, 1, True, True)
        pred = pred.t()
        correct = pred.eq(targets.view(1, -1).expand_as(pred))
        out = []
        for k in topk:
            correct_k = correct[:k].reshape(-1).float().sum(0)
            out.append(correct_k / targets.size(0))
        return out


def run_epoch(
    model: nn.Module,
    loader: DataLoader,
    criterion: nn.Module,
    optimizer: Optional[torch.optim.Optimizer],
    device: torch.device,
    scaler: torch.amp.GradScaler,
    num_classes: int,
    cfg: TrainConfig,
    ema: Optional[ModelEMA],
    is_train: bool,
    accum_steps: int,
) -> Dict[str, float]:
    model.train(is_train)

    total_loss = 0.0
    total_top1 = 0.0
    total_top5 = 0.0
    total_samples = 0

    if is_train:
        optimizer.zero_grad(set_to_none=True)

    autocast_enabled = device.type == "cuda"
    total_batches = len(loader)
    progress_every = max(1, int(getattr(cfg, "progress_every", 120)))

    for step, (images, targets) in enumerate(loader, start=1):
        images = images.to(device, non_blocking=True)
        targets = targets.to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=autocast_enabled):
            if is_train:
                images_mixed, soft_targets = mixup_cutmix(
                    images,
                    targets,
                    cfg.mixup_alpha,
                    cfg.cutmix_alpha,
                    cfg.mix_probability,
                    num_classes,
                )
                logits = model(images_mixed)
                loss = criterion(logits, soft_targets)
            else:
                logits = model(images)
                loss = criterion(logits, targets)

            loss = loss / accum_steps

        if is_train:
            scaler.scale(loss).backward()
            if step % accum_steps == 0 or step == total_batches:
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip_norm)
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad(set_to_none=True)
                if ema is not None:
                    ema.update(model)

        with torch.no_grad():
            top1, top5 = topk_accuracy(logits, targets, topk=(1, 5))

        bs = images.size(0)
        total_samples += bs
        total_loss += loss.item() * accum_steps * bs
        total_top1 += float(top1.item()) * bs
        total_top5 += float(top5.item()) * bs

        if is_train and (step % progress_every == 0 or step == total_batches):
            avg_loss = total_loss / max(1, total_samples)
            avg_top1 = total_top1 / max(1, total_samples)
            print(f"  [train] batch {step}/{total_batches} | avg_loss={avg_loss:.4f} | avg_top1={avg_top1:.4f}")

    return {
        "loss": total_loss / max(1, total_samples),
        "top1": total_top1 / max(1, total_samples),
        "top5": total_top5 / max(1, total_samples),
    }


@torch.no_grad()
def evaluate_with_tta(
    model: nn.Module,
    loader: DataLoader,
    criterion: nn.Module,
    device: torch.device,
    use_tta: bool,
) -> Dict[str, float]:
    model.eval()
    total_loss = 0.0
    total_top1 = 0.0
    total_top5 = 0.0
    total_samples = 0

    for images, targets in loader:
        images = images.to(device, non_blocking=True)
        targets = targets.to(device, non_blocking=True)

        logits = model(images)
        if use_tta:
            logits_flip = model(torch.flip(images, dims=[3]))
            logits = (logits + logits_flip) / 2.0

        loss = criterion(logits, targets)
        top1, top5 = topk_accuracy(logits, targets, topk=(1, 5))

        bs = images.size(0)
        total_samples += bs
        total_loss += float(loss.item()) * bs
        total_top1 += float(top1.item()) * bs
        total_top5 += float(top5.item()) * bs

    return {
        "loss": total_loss / max(1, total_samples),
        "top1": total_top1 / max(1, total_samples),
        "top5": total_top5 / max(1, total_samples),
    }


def freeze_backbone(model: nn.Module, freeze: bool):
    for p in model.parameters():
        p.requires_grad = not freeze

    if hasattr(model, "head") and isinstance(model.head, nn.Module):
        for p in model.head.parameters():
            p.requires_grad = True

    if hasattr(model, "fc") and isinstance(model.fc, nn.Module):
        for p in model.fc.parameters():
            p.requires_grad = True


def get_trainable_parameters(model: nn.Module, backbone_lr: float, head_lr: float, weight_decay: float):
    head_params = []
    backbone_params = []

    for name, p in model.named_parameters():
        if not p.requires_grad:
            continue
        if any(k in name for k in ["head", "fc", "classifier"]):
            head_params.append(p)
        else:
            backbone_params.append(p)

    param_groups = []
    if backbone_params:
        param_groups.append({"params": backbone_params, "lr": backbone_lr, "weight_decay": weight_decay})
    if head_params:
        param_groups.append({"params": head_params, "lr": head_lr, "weight_decay": weight_decay})
    return param_groups


def build_scheduler(optimizer: torch.optim.Optimizer, warmup_epochs: int, total_epochs: int):
    warmup_epochs = max(0, warmup_epochs)
    total_epochs = max(1, total_epochs)
    if warmup_epochs > 0:
        warmup = torch.optim.lr_scheduler.LinearLR(optimizer, start_factor=0.12, total_iters=warmup_epochs)
        cosine = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=max(1, total_epochs - warmup_epochs))
        return torch.optim.lr_scheduler.SequentialLR(optimizer, [warmup, cosine], milestones=[warmup_epochs])
    return torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=total_epochs)


def pick_num_workers(explicit_workers: int) -> int:
    if explicit_workers >= 0:
        return explicit_workers
    if os.name == "nt":
        return 0
    return min(8, max(2, (os.cpu_count() or 4) // 2))


def fit(project_root: Path, cfg: TrainConfig):
    set_seed(cfg.seed)
    Image.MAX_IMAGE_PIXELS = None

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    wikiart_dir, train_csv, val_csv = discover_paths(project_root)

    train_df = load_style_csv(train_csv)
    val_df = load_style_csv(val_csv)

    train_df = filter_existing_rows(train_df, wikiart_dir, split_name="train")
    val_df = filter_existing_rows(val_df, wikiart_dir, split_name="val")

    if len(train_df) == 0 or len(val_df) == 0:
        raise RuntimeError("No usable data after filtering missing files.")

    eval_val_df, eval_test_df = make_eval_split(val_df, seed=cfg.seed)

    num_classes = int(max(train_df["label"].max(), val_df["label"].max()) + 1)

    train_tfms, eval_tfms = build_transforms(cfg.image_size)

    train_ds = WikiArtStyleDataset(train_df, wikiart_dir, transform=train_tfms)
    val_ds = WikiArtStyleDataset(eval_val_df, wikiart_dir, transform=eval_tfms)
    test_ds = WikiArtStyleDataset(eval_test_df, wikiart_dir, transform=eval_tfms)

    num_workers = pick_num_workers(cfg.num_workers)
    pin_memory = device.type == "cuda"

    sampler = None
    shuffle = True
    if cfg.use_weighted_sampler:
        sampler = create_weighted_sampler(train_df["label"].values)
        shuffle = False

    train_loader = DataLoader(
        train_ds,
        batch_size=cfg.batch_size,
        sampler=sampler,
        shuffle=shuffle,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=num_workers > 0,
        drop_last=True,
    )
    val_loader = DataLoader(
        val_ds,
        batch_size=cfg.batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=num_workers > 0,
    )
    test_loader = DataLoader(
        test_ds,
        batch_size=cfg.batch_size,
        shuffle=False,
        num_workers=num_workers,
        pin_memory=pin_memory,
        persistent_workers=num_workers > 0,
    )

    if cfg.fast_mode:
        cfg.head_epochs = min(cfg.head_epochs, 1)
        cfg.ft_epochs = min(cfg.ft_epochs, 4)
        cfg.patience = min(cfg.patience, 2)

    print(f"Device: {device}")
    print(f"Model: {cfg.model_name}")
    print(f"Train/Val/Test sizes: {len(train_ds)}/{len(val_ds)}/{len(test_ds)}")
    print(f"Classes: {num_classes}")

    model = timm.create_model(cfg.model_name, pretrained=True, num_classes=num_classes)
    model.to(device)

    eval_criterion = nn.CrossEntropyLoss(label_smoothing=cfg.label_smoothing)
    train_criterion = SoftTargetCrossEntropyWithLabelSmoothing(smoothing=cfg.label_smoothing)

    grad_accum_steps = max(1, math.ceil(cfg.effective_batch_size / cfg.batch_size))

    scaler = torch.amp.GradScaler(device="cuda", enabled=device.type == "cuda")
    ema = ModelEMA(model, decay=cfg.ema_decay)

    history: List[Dict] = []
    best_val_top1 = -1.0
    best_epoch = -1
    patience_left = cfg.patience

    checkpoint_dir = project_root / "models"
    checkpoint_dir.mkdir(parents=True, exist_ok=True)
    checkpoint_path = checkpoint_dir / "wikiart_test7_best.pt"

    epoch_counter = 0

    for stage_name, stage_epochs, freeze_backbone_flag, lr_backbone, lr_head in [
        ("head-only", cfg.head_epochs, True, cfg.head_lr, cfg.head_lr),
        ("fine-tune", cfg.ft_epochs, False, cfg.ft_backbone_lr, cfg.ft_head_lr),
    ]:
        if stage_epochs <= 0:
            continue

        freeze_backbone(model, freeze=freeze_backbone_flag)
        param_groups = get_trainable_parameters(
            model,
            backbone_lr=lr_backbone,
            head_lr=lr_head,
            weight_decay=cfg.weight_decay,
        )
        optimizer = torch.optim.AdamW(param_groups)
        scheduler = build_scheduler(
            optimizer,
            warmup_epochs=min(cfg.warmup_epochs, stage_epochs),
            total_epochs=stage_epochs,
        )

        for _ in range(stage_epochs):
            epoch_counter += 1

            train_metrics = run_epoch(
                model=model,
                loader=train_loader,
                criterion=train_criterion,
                optimizer=optimizer,
                device=device,
                scaler=scaler,
                num_classes=num_classes,
                cfg=cfg,
                ema=ema,
                is_train=True,
                accum_steps=grad_accum_steps,
            )

            eval_model = ema.ema_model if ema is not None else model
            val_metrics = evaluate_with_tta(
                model=eval_model,
                loader=val_loader,
                criterion=eval_criterion,
                device=device,
                use_tta=cfg.tta,
            )

            scheduler.step()

            current_lr = optimizer.param_groups[0]["lr"]
            row = {
                "epoch": epoch_counter,
                "stage": stage_name,
                "lr": current_lr,
                "train_loss": train_metrics["loss"],
                "train_top1": train_metrics["top1"],
                "train_top5": train_metrics["top5"],
                "val_loss": val_metrics["loss"],
                "val_top1": val_metrics["top1"],
                "val_top5": val_metrics["top5"],
            }
            history.append(row)

            print(
                f"Epoch {epoch_counter:02d} | {stage_name:9s} | "
                f"lr={current_lr:.2e} | "
                f"train_loss={row['train_loss']:.4f}, train_acc={row['train_top1']:.4f} | "
                f"val_loss={row['val_loss']:.4f}, val_acc={row['val_top1']:.4f}, val_top5={row['val_top5']:.4f}"
            )

            improved = row["val_top1"] > best_val_top1
            if improved:
                best_val_top1 = row["val_top1"]
                best_epoch = epoch_counter
                patience_left = cfg.patience
                checkpoint = {
                    "model_state": copy.deepcopy(eval_model.state_dict()),
                    "config": asdict(cfg),
                    "best_val_top1": best_val_top1,
                    "best_epoch": best_epoch,
                    "num_classes": num_classes,
                    "model_name": cfg.model_name,
                    "timestamp_utc": datetime.now(timezone.utc).isoformat(),
                }
                torch.save(checkpoint, checkpoint_path)
            else:
                patience_left -= 1

            if patience_left <= 0:
                print(f"Early stopping at epoch {epoch_counter} (best epoch: {best_epoch}).")
                break

        if patience_left <= 0:
            break

    if checkpoint_path.exists():
        state = torch.load(checkpoint_path, map_location=device)
        model.load_state_dict(state["model_state"])

    final_val_metrics = evaluate_with_tta(model, val_loader, eval_criterion, device=device, use_tta=cfg.tta)
    final_test_metrics = evaluate_with_tta(model, test_loader, eval_criterion, device=device, use_tta=cfg.tta)

    print("\nFinal evaluation")
    print(
        f"Validation -> loss: {final_val_metrics['loss']:.4f}, "
        f"top1: {final_val_metrics['top1']:.4f}, top5: {final_val_metrics['top5']:.4f}"
    )
    print(
        f"Test       -> loss: {final_test_metrics['loss']:.4f}, "
        f"top1: {final_test_metrics['top1']:.4f}, top5: {final_test_metrics['top5']:.4f}"
    )
    print(f"Best checkpoint: {checkpoint_path}")
    print(f"Best epoch: {best_epoch}")
    print(f"Best val_top1: {best_val_top1:.4f}")

    history_df = pd.DataFrame(history)
    results_dir = project_root / "models" / "results"
    results_dir.mkdir(parents=True, exist_ok=True)

    history_csv = results_dir / "wikiart_test7_history.csv"
    history_df.to_csv(history_csv, index=False)

    summary_row = {
        "notebook": "wikiart_style_classification_test7_max_accuracy.ipynb",
        "exists": True,
        "model_name": cfg.model_name,
        "val_loss": final_val_metrics["loss"],
        "val_top1": final_val_metrics["top1"],
        "val_top5": final_val_metrics["top5"],
        "test_loss": final_test_metrics["loss"],
        "test_top1": final_test_metrics["top1"],
        "test_top5": final_test_metrics["top5"],
        "best_val_top1": best_val_top1,
        "best_epoch": best_epoch,
        "experiment": "test7",
        "saved_at_utc": datetime.now(timezone.utc).isoformat(),
    }

    summary_csv = results_dir / "wikiart_tests_1_to_7_summary.csv"
    prior_summary_csv = results_dir / "wikiart_tests_1_to_6_summary.csv"

    summary_rows = []
    if prior_summary_csv.exists():
        prior_df = pd.read_csv(prior_summary_csv)
        summary_rows.extend(prior_df.to_dict(orient="records"))

    summary_rows = [r for r in summary_rows if str(r.get("experiment", "")).lower() != "test7"]
    summary_rows.append(summary_row)

    summary_df = pd.DataFrame(summary_rows)
    if "experiment" in summary_df.columns:
        summary_df = summary_df.sort_values("experiment").reset_index(drop=True)
    summary_df.to_csv(summary_csv, index=False)

    print(f"Saved history: {history_csv}")
    print(f"Saved summary: {summary_csv}")

    return history_df, final_val_metrics, final_test_metrics

# %%
# Progress override: print epoch start + progress every N batches

def run_epoch(
    model: nn.Module,
    loader: DataLoader,
    criterion: nn.Module,
    optimizer: Optional[torch.optim.Optimizer],
    device: torch.device,
    scaler: torch.amp.GradScaler,
    num_classes: int,
    cfg: TrainConfig,
    ema: Optional[ModelEMA],
    is_train: bool,
    accum_steps: int,
) -> Dict[str, float]:
    model.train(is_train)

    total_loss = 0.0
    total_top1 = 0.0
    total_top5 = 0.0
    total_samples = 0

    if is_train:
        optimizer.zero_grad(set_to_none=True)
        run_epoch.epoch_counter = getattr(run_epoch, "epoch_counter", 0) + 1
        print(f"\n--- Starting epoch {run_epoch.epoch_counter} ---")

    autocast_enabled = device.type == "cuda"
    total_batches = len(loader)
    progress_every = max(1, int(getattr(cfg, "progress_every", 300)))

    for step, (images, targets) in enumerate(loader, start=1):
        images = images.to(device, non_blocking=True)
        targets = targets.to(device, non_blocking=True)

        with torch.amp.autocast(device_type="cuda", enabled=autocast_enabled):
            if is_train:
                images_mixed, soft_targets = mixup_cutmix(
                    images,
                    targets,
                    cfg.mixup_alpha,
                    cfg.cutmix_alpha,
                    cfg.mix_probability,
                    num_classes,
                )
                logits = model(images_mixed)
                loss = criterion(logits, soft_targets)
            else:
                logits = model(images)
                loss = criterion(logits, targets)

            loss = loss / accum_steps

        if is_train:
            scaler.scale(loss).backward()
            if step % accum_steps == 0 or step == total_batches:
                scaler.unscale_(optimizer)
                torch.nn.utils.clip_grad_norm_(model.parameters(), cfg.grad_clip_norm)
                scaler.step(optimizer)
                scaler.update()
                optimizer.zero_grad(set_to_none=True)
                if ema is not None:
                    ema.update(model)

        with torch.no_grad():
            top1, top5 = topk_accuracy(logits, targets, topk=(1, 5))

        bs = images.size(0)
        total_samples += bs
        total_loss += loss.item() * accum_steps * bs
        total_top1 += float(top1.item()) * bs
        total_top5 += float(top5.item()) * bs

        if is_train and (step % progress_every == 0 or step == total_batches):
            avg_loss = total_loss / max(1, total_samples)
            avg_top1 = total_top1 / max(1, total_samples)
            print(
                f"  [train] epoch {run_epoch.epoch_counter} | "
                f"batch {step}/{total_batches} | avg_loss={avg_loss:.4f} | avg_top1={avg_top1:.4f}"
            )

    return {
        "loss": total_loss / max(1, total_samples),
        "top1": total_top1 / max(1, total_samples),
        "top5": total_top5 / max(1, total_samples),
    }


# Wrap fit so epoch counter resets on each fresh training run
_original_fit = fit

def fit(project_root: Path, cfg: TrainConfig):
    run_epoch.epoch_counter = 0
    return _original_fit(project_root, cfg)

print("Progress override active: epoch starts + every 300 batches.")
# Out:
# Progress override active: epoch starts + every 300 batches.

# %%
cfg = TrainConfig(
    model_name="vit_base_patch16_384.augreg_in21k_ft_in1k",
    image_size=384,
    batch_size=8,
    effective_batch_size=64,
    head_epochs=5,
    ft_epochs=56,
    patience=16,
    warmup_epochs=4,
    head_lr=4e-4,
    ft_backbone_lr=4e-6,
    ft_head_lr=1.8e-5,
    weight_decay=1.2e-4,
    mixup_alpha=0.6,
    cutmix_alpha=1.0,
    mix_probability=0.9,
    label_smoothing=0.08,
    ema_decay=0.99985,
    grad_clip_norm=1.0,
    tta=True,
    use_weighted_sampler=True,
    seed=42,
    num_workers=0,
    progress_every=300,
)

# This is a max-accuracy preset (long run).

# %%
history_df, final_val, final_test = fit(Path.cwd(), cfg)
# Out:
# [train] Filtered out 2 missing files.
# Device: cuda
# Model: vit_base_patch16_384.augreg_in21k_ft_in1k
# Train/Val/Test sizes: 57023/12213/12208
# Classes: 27
#
# --- Starting epoch 1 ---
#   [train] epoch 1 | batch 300/7127 | avg_loss=4.2530 | avg_top1=0.0358
#   [train] epoch 1 | batch 600/7127 | avg_loss=4.0754 | avg_top1=0.0479
#   [train] epoch 1 | batch 900/7127 | avg_loss=3.9544 | avg_top1=0.0596
#   [train] epoch 1 | batch 1200/7127 | avg_loss=3.8572 | avg_top1=0.0654
#   [train] epoch 1 | batch 1500/7127 | avg_loss=3.7770 | avg_top1=0.0717
#   [train] epoch 1 | batch 1800/7127 | avg_loss=3.7106 | avg_top1=0.0778
#   [train] epoch 1 | batch 2100/7127 | avg_loss=3.6516 | avg_top1=0.0824
#   [train] epoch 1 | batch 2400/7127 | avg_loss=3.5949 | avg_top1=0.0865
#   [train] epoch 1 | batch 2700/7127 | avg_loss=3.5505 | avg_top1=0.0897
#   [train] epoch 1 | batch 3000/7127 | avg_loss=3.5109 | avg_top1=0.0935
#   [train] epoch 1 | batch 3300/7127 | avg_loss=3.4679 | avg_top1=0.0981
#   [train] epoch 1 | batch 3600/7127 | avg_loss=3.4323 | avg_top1=0.1018
#   [train] epoch 1 | batch 3900/7127 | avg_loss=3.3985 | avg_top1=0.1056
#   [train] epoch 1 | batch 4200/7127 | avg_loss=3.3662 | avg_top1=0.1089
#   [train] epoch 1 | batch 4500/7127 | avg_loss=3.3372 | avg_top1=0.1121
#   [train] epoch 1 | batch 4800/7127 | avg_loss=3.3091 | avg_top1=0.1151
#   [train] epoch 1 | batch 5100/7127 | avg_loss=3.2810 | avg_top1=0.1182
#   [train] epoch 1 | batch 5400/7127 | avg_loss=3.2568 | avg_top1=0.1216
#   [train] epoch 1 | batch 5700/7127 | avg_loss=3.2307 | avg_top1=0.1236
#   [train] epoch 1 | batch 6000/7127 | avg_loss=3.2074 | avg_top1=0.1264
#   [train] epoch 1 | batch 6300/7127 | avg_loss=3.1856 | avg_top1=0.1297
#   [train] epoch 1 | batch 6600/7127 | avg_loss=3.1649 | avg_top1=0.1323
#   [train] epoch 1 | batch 6900/7127 | avg_loss=3.1455 | avg_top1=0.1353
#   [train] epoch 1 | batch 7127/7127 | avg_loss=3.1302 | avg_top1=0.1372
# Epoch 01 | head-only | lr=1.36e-04 | train_loss=3.1302, train_acc=0.1372 | val_loss=4.3348, val_acc=0.0400, val_top5=0.2165
#
# --- Starting epoch 2 ---
#   [train] epoch 2 | batch 300/7127 | avg_loss=2.6799 | avg_top1=0.2271
#   [train] epoch 2 | batch 600/7127 | avg_loss=2.6806 | avg_top1=0.2160
#   [train] epoch 2 | batch 900/7127 | avg_loss=2.6647 | avg_top1=0.2178
#   [train] epoch 2 | batch 1200/7127 | avg_loss=2.6400 | avg_top1=0.2206
#   [train] epoch 2 | batch 1500/7127 | avg_loss=2.6177 | avg_top1=0.2229
#   [train] epoch 2 | batch 1800/7127 | avg_loss=2.6086 | avg_top1=0.2234
#   [train] epoch 2 | batch 2100/7127 | avg_loss=2.5912 | avg_top1=0.2239
#   [train] epoch 2 | batch 2400/7127 | avg_loss=2.5789 | avg_top1=0.2268
#   [train] epoch 2 | batch 2700/7127 | avg_loss=2.5695 | avg_top1=0.2301
#   [train] epoch 2 | batch 3000/7127 | avg_loss=2.5574 | avg_top1=0.2310
#   [train] epoch 2 | batch 3300/7127 | avg_loss=2.5462 | avg_top1=0.2342
#   [train] epoch 2 | batch 3600/7127 | avg_loss=2.5328 | avg_top1=0.2376
#   [train] epoch 2 | batch 3900/7127 | avg_loss=2.5249 | avg_top1=0.2386
#   [train] epoch 2 | batch 4200/7127 | avg_loss=2.5151 | avg_top1=0.2395
#   [train] epoch 2 | batch 4500/7127 | avg_loss=2.5092 | avg_top1=0.2415
#   [train] epoch 2 | batch 4800/7127 | avg_loss=2.5019 | avg_top1=0.2439
#   [train] epoch 2 | batch 5100/7127 | avg_loss=2.4929 | avg_top1=0.2454
#   [train] epoch 2 | batch 5400/7127 | avg_loss=2.4855 | avg_top1=0.2474
#   [train] epoch 2 | batch 5700/7127 | avg_loss=2.4785 | avg_top1=0.2487
#   [train] epoch 2 | batch 6000/7127 | avg_loss=2.4714 | avg_top1=0.2506
#   [train] epoch 2 | batch 6300/7127 | avg_loss=2.4642 | avg_top1=0.2522
#   [train] epoch 2 | batch 6600/7127 | avg_loss=2.4582 | avg_top1=0.2535
#   [train] epoch 2 | batch 6900/7127 | avg_loss=2.4517 | avg_top1=0.2545
#   [train] epoch 2 | batch 7127/7127 | avg_loss=2.4462 | avg_top1=0.2551
# Epoch 02 | head-only | lr=2.24e-04 | train_loss=2.4462, train_acc=0.2551 | val_loss=3.8456, val_acc=0.0640, val_top5=0.3010
#
# --- Starting epoch 3 ---
#   [train] epoch 3 | batch 300/7127 | avg_loss=2.3296 | avg_top1=0.2754
#   [train] epoch 3 | batch 600/7127 | avg_loss=2.3140 | avg_top1=0.2742
#   [train] epoch 3 | batch 900/7127 | avg_loss=2.3218 | avg_top1=0.2708
#   [train] epoch 3 | batch 1200/7127 | avg_loss=2.3122 | avg_top1=0.2782
#   [train] epoch 3 | batch 1500/7127 | avg_loss=2.3119 | avg_top1=0.2782
#   [train] epoch 3 | batch 1800/7127 | avg_loss=2.3064 | avg_top1=0.2783
#   [train] epoch 3 | batch 2100/7127 | avg_loss=2.3010 | avg_top1=0.2824
#   [train] epoch 3 | batch 2400/7127 | avg_loss=2.2990 | avg_top1=0.2832
#   [train] epoch 3 | batch 2700/7127 | avg_loss=2.2921 | avg_top1=0.2856
#   [train] epoch 3 | batch 3000/7127 | avg_loss=2.2861 | avg_top1=0.2873
#   [train] epoch 3 | batch 3300/7127 | avg_loss=2.2851 | avg_top1=0.2881
#   [train] epoch 3 | batch 3600/7127 | avg_loss=2.2754 | avg_top1=0.2911
#   [train] epoch 3 | batch 3900/7127 | avg_loss=2.2706 | avg_top1=0.2912
#   [train] epoch 3 | batch 4200/7127 | avg_loss=2.2674 | avg_top1=0.2918
#   [train] epoch 3 | batch 4500/7127 | avg_loss=2.2648 | avg_top1=0.2919
#   [train] epoch 3 | batch 4800/7127 | avg_loss=2.2616 | avg_top1=0.2918
#   [train] epoch 3 | batch 5100/7127 | avg_loss=2.2594 | avg_top1=0.2927
#   [train] epoch 3 | batch 5400/7127 | avg_loss=2.2559 | avg_top1=0.2932
#   [train] epoch 3 | batch 5700/7127 | avg_loss=2.2517 | avg_top1=0.2943
#   [train] epoch 3 | batch 6000/7127 | avg_loss=2.2473 | avg_top1=0.2955
#   [train] epoch 3 | batch 6300/7127 | avg_loss=2.2422 | avg_top1=0.2971
#   [train] epoch 3 | batch 6600/7127 | avg_loss=2.2395 | avg_top1=0.2974
#   [train] epoch 3 | batch 6900/7127 | avg_loss=2.2370 | avg_top1=0.2980
#   [train] epoch 3 | batch 7127/7127 | avg_loss=2.2339 | avg_top1=0.2995
# Epoch 03 | head-only | lr=3.12e-04 | train_loss=2.2339, train_acc=0.2995 | val_loss=3.3846, val_acc=0.1036, val_top5=0.4071
#
# --- Starting epoch 4 ---
#   [train] epoch 4 | batch 300/7127 | avg_loss=2.1859 | avg_top1=0.3137
#   [train] epoch 4 | batch 600/7127 | avg_loss=2.1896 | avg_top1=0.3117
#   [train] epoch 4 | batch 900/7127 | avg_loss=2.1666 | avg_top1=0.3165
#   [train] epoch 4 | batch 1200/7127 | avg_loss=2.1727 | avg_top1=0.3134
#   [train] epoch 4 | batch 1500/7127 | avg_loss=2.1694 | avg_top1=0.3183
#   [train] epoch 4 | batch 1800/7127 | avg_loss=2.1686 | avg_top1=0.3199
#   [train] epoch 4 | batch 2100/7127 | avg_loss=2.1711 | avg_top1=0.3214
#   [train] epoch 4 | batch 2400/7127 | avg_loss=2.1687 | avg_top1=0.3227
#   [train] epoch 4 | batch 2700/7127 | avg_loss=2.1673 | avg_top1=0.3226
#   [train] epoch 4 | batch 3000/7127 | avg_loss=2.1683 | avg_top1=0.3211
#   [train] epoch 4 | batch 3300/7127 | avg_loss=2.1640 | avg_top1=0.3231
#   [train] epoch 4 | batch 3600/7127 | avg_loss=2.1667 | avg_top1=0.3233
#   [train] epoch 4 | batch 3900/7127 | avg_loss=2.1652 | avg_top1=0.3238
#   [train] epoch 4 | batch 4200/7127 | avg_loss=2.1630 | avg_top1=0.3232
#   [train] epoch 4 | batch 4500/7127 | avg_loss=2.1607 | avg_top1=0.3248
#   [train] epoch 4 | batch 4800/7127 | avg_loss=2.1583 | avg_top1=0.3262
#   [train] epoch 4 | batch 5100/7127 | avg_loss=2.1586 | avg_top1=0.3269
#   [train] epoch 4 | batch 5400/7127 | avg_loss=2.1545 | avg_top1=0.3283
#   [train] epoch 4 | batch 5700/7127 | avg_loss=2.1526 | avg_top1=0.3278
#   [train] epoch 4 | batch 6000/7127 | avg_loss=2.1529 | avg_top1=0.3271
#   [train] epoch 4 | batch 6300/7127 | avg_loss=2.1506 | avg_top1=0.3278
#   [train] epoch 4 | batch 6600/7127 | avg_loss=2.1509 | avg_top1=0.3273
#   [train] epoch 4 | batch 6900/7127 | avg_loss=2.1490 | avg_top1=0.3272
#   [train] epoch 4 | batch 7127/7127 | avg_loss=2.1474 | avg_top1=0.3281
# Epoch 04 | head-only | lr=4.00e-04 | train_loss=2.1474, train_acc=0.3281 | val_loss=2.9976, val_acc=0.1571, val_top5=0.5316
#
# --- Starting epoch 5 ---
#   [train] epoch 5 | batch 300/7127 | avg_loss=2.1334 | avg_top1=0.3579
#   [train] epoch 5 | batch 600/7127 | avg_loss=2.1102 | avg_top1=0.3515
#   [train] epoch 5 | batch 900/7127 | avg_loss=2.1031 | avg_top1=0.3486
#   [train] epoch 5 | batch 1200/7127 | avg_loss=2.1118 | avg_top1=0.3489
#   [train] epoch 5 | batch 1500/7127 | avg_loss=2.1274 | avg_top1=0.3419
#   [train] epoch 5 | batch 1800/7127 | avg_loss=2.1224 | avg_top1=0.3401
#   [train] epoch 5 | batch 2100/7127 | avg_loss=2.1278 | avg_top1=0.3403
#   [train] epoch 5 | batch 2400/7127 | avg_loss=2.1335 | avg_top1=0.3364
#   [train] epoch 5 | batch 2700/7127 | avg_loss=2.1344 | avg_top1=0.3371
#   [train] epoch 5 | batch 3000/7127 | avg_loss=2.1290 | avg_top1=0.3387
#   [train] epoch 5 | batch 3300/7127 | avg_loss=2.1290 | avg_top1=0.3392
#   [train] epoch 5 | batch 3600/7127 | avg_loss=2.1272 | avg_top1=0.3377
#   [train] epoch 5 | batch 3900/7127 | avg_loss=2.1274 | avg_top1=0.3394
#   [train] epoch 5 | batch 4200/7127 | avg_loss=2.1278 | avg_top1=0.3388
#   [train] epoch 5 | batch 4500/7127 | avg_loss=2.1253 | avg_top1=0.3380
#   [train] epoch 5 | batch 4800/7127 | avg_loss=2.1242 | avg_top1=0.3380
#   [train] epoch 5 | batch 5100/7127 | avg_loss=2.1210 | avg_top1=0.3374
#   [train] epoch 5 | batch 5400/7127 | avg_loss=2.1200 | avg_top1=0.3366
#   [train] epoch 5 | batch 5700/7127 | avg_loss=2.1217 | avg_top1=0.3356
#   [train] epoch 5 | batch 6000/7127 | avg_loss=2.1203 | avg_top1=0.3358
#   [train] epoch 5 | batch 6300/7127 | avg_loss=2.1192 | avg_top1=0.3365
#   [train] epoch 5 | batch 6600/7127 | avg_loss=2.1192 | avg_top1=0.3364
#   [train] epoch 5 | batch 6900/7127 | avg_loss=2.1180 | avg_top1=0.3368
#   [train] epoch 5 | batch 7127/7127 | avg_loss=2.1189 | avg_top1=0.3366
# Epoch 05 | head-only | lr=0.00e+00 | train_loss=2.1189, train_acc=0.3366 | val_loss=2.6882, val_acc=0.2210, val_top5=0.6414
#
# --- Starting epoch 6 ---
#   [train] epoch 6 | batch 300/7127 | avg_loss=2.0998 | avg_top1=0.3267
#   [train] epoch 6 | batch 600/7127 | avg_loss=2.0813 | avg_top1=0.3350
#   [train] epoch 6 | batch 900/7127 | avg_loss=2.0546 | avg_top1=0.3485
#   [train] epoch 6 | batch 1200/7127 | avg_loss=2.0349 | avg_top1=0.3595
#   [train] epoch 6 | batch 1500/7127 | avg_loss=2.0298 | avg_top1=0.3594
#   [train] epoch 6 | batch 1800/7127 | avg_loss=2.0303 | avg_top1=0.3637
#   [train] epoch 6 | batch 2100/7127 | avg_loss=2.0239 | avg_top1=0.3642
#   [train] epoch 6 | batch 2400/7127 | avg_loss=2.0137 | avg_top1=0.3659
#   [train] epoch 6 | batch 2700/7127 | avg_loss=2.0096 | avg_top1=0.3678
#   [train] epoch 6 | batch 3000/7127 | avg_loss=2.0082 | avg_top1=0.3684
#   [train] epoch 6 | batch 3300/7127 | avg_loss=2.0032 | avg_top1=0.3689
#   [train] epoch 6 | batch 3600/7127 | avg_loss=1.9988 | avg_top1=0.3713
#   [train] epoch 6 | batch 3900/7127 | avg_loss=1.9921 | avg_top1=0.3741
#   [train] epoch 6 | batch 4200/7127 | avg_loss=1.9820 | avg_top1=0.3772
#   [train] epoch 6 | batch 4500/7127 | avg_loss=1.9777 | avg_top1=0.3777
#   [train] epoch 6 | batch 4800/7127 | avg_loss=1.9731 | avg_top1=0.3789
#   [train] epoch 6 | batch 5100/7127 | avg_loss=1.9680 | avg_top1=0.3800
#   [train] epoch 6 | batch 5400/7127 | avg_loss=1.9618 | avg_top1=0.3808
#   [train] epoch 6 | batch 5700/7127 | avg_loss=1.9607 | avg_top1=0.3817
#   [train] epoch 6 | batch 6000/7127 | avg_loss=1.9561 | avg_top1=0.3821
#   [train] epoch 6 | batch 6300/7127 | avg_loss=1.9517 | avg_top1=0.3840
#   [train] epoch 6 | batch 6600/7127 | avg_loss=1.9486 | avg_top1=0.3844
#   [train] epoch 6 | batch 6900/7127 | avg_loss=1.9453 | avg_top1=0.3853
#   [train] epoch 6 | batch 7127/7127 | avg_loss=1.9445 | avg_top1=0.3846
# Epoch 06 | fine-tune | lr=1.36e-06 | train_loss=1.9445, train_acc=0.3846 | val_loss=2.4379, val_acc=0.2954, val_top5=0.7328
#
# --- Starting epoch 7 ---
#   [train] epoch 7 | batch 300/7127 | avg_loss=1.7984 | avg_top1=0.4083
#   [train] epoch 7 | batch 600/7127 | avg_loss=1.7962 | avg_top1=0.4125
#   [train] epoch 7 | batch 900/7127 | avg_loss=1.8215 | avg_top1=0.4158
#   [train] epoch 7 | batch 1200/7127 | avg_loss=1.8307 | avg_top1=0.4035
#   [train] epoch 7 | batch 1500/7127 | avg_loss=1.8169 | avg_top1=0.4093
#   [train] epoch 7 | batch 1800/7127 | avg_loss=1.8186 | avg_top1=0.4075
#   [train] epoch 7 | batch 2100/7127 | avg_loss=1.8274 | avg_top1=0.4073
#   [train] epoch 7 | batch 2400/7127 | avg_loss=1.8187 | avg_top1=0.4074
#   [train] epoch 7 | batch 2700/7127 | avg_loss=1.8183 | avg_top1=0.4102
#   [train] epoch 7 | batch 3000/7127 | avg_loss=1.8156 | avg_top1=0.4119
#   [train] epoch 7 | batch 3300/7127 | avg_loss=1.8148 | avg_top1=0.4111
#   [train] epoch 7 | batch 3600/7127 | avg_loss=1.8137 | avg_top1=0.4124
#   [train] epoch 7 | batch 3900/7127 | avg_loss=1.8139 | avg_top1=0.4122
#   [train] epoch 7 | batch 4200/7127 | avg_loss=1.8124 | avg_top1=0.4137
#   [train] epoch 7 | batch 4500/7127 | avg_loss=1.8083 | avg_top1=0.4154
#   [train] epoch 7 | batch 4800/7127 | avg_loss=1.8043 | avg_top1=0.4146
#   [train] epoch 7 | batch 5100/7127 | avg_loss=1.8017 | avg_top1=0.4150
#   [train] epoch 7 | batch 5400/7127 | avg_loss=1.7995 | avg_top1=0.4155
#   [train] epoch 7 | batch 5700/7127 | avg_loss=1.7941 | avg_top1=0.4177
#   [train] epoch 7 | batch 6000/7127 | avg_loss=1.7893 | avg_top1=0.4198
#   [train] epoch 7 | batch 6300/7127 | avg_loss=1.7862 | avg_top1=0.4196
#   [train] epoch 7 | batch 6600/7127 | avg_loss=1.7816 | avg_top1=0.4210
#   [train] epoch 7 | batch 6900/7127 | avg_loss=1.7813 | avg_top1=0.4210
#   [train] epoch 7 | batch 7127/7127 | avg_loss=1.7783 | avg_top1=0.4218
# Epoch 07 | fine-tune | lr=2.24e-06 | train_loss=1.7783, train_acc=0.4218 | val_loss=2.2276, val_acc=0.3649, val_top5=0.8024
#
# --- Starting epoch 8 ---
#   [train] epoch 8 | batch 300/7127 | avg_loss=1.7138 | avg_top1=0.4462
#   [train] epoch 8 | batch 600/7127 | avg_loss=1.6914 | avg_top1=0.4404
#   [train] epoch 8 | batch 900/7127 | avg_loss=1.6920 | avg_top1=0.4382
#   [train] epoch 8 | batch 1200/7127 | avg_loss=1.6926 | avg_top1=0.4404
#   [train] epoch 8 | batch 1500/7127 | avg_loss=1.6978 | avg_top1=0.4364
#   [train] epoch 8 | batch 1800/7127 | avg_loss=1.6934 | avg_top1=0.4383
#   [train] epoch 8 | batch 2100/7127 | avg_loss=1.6940 | avg_top1=0.4384
#   [train] epoch 8 | batch 2400/7127 | avg_loss=1.6930 | avg_top1=0.4377
#   [train] epoch 8 | batch 2700/7127 | avg_loss=1.6887 | avg_top1=0.4401
#   [train] epoch 8 | batch 3000/7127 | avg_loss=1.6885 | avg_top1=0.4398
#   [train] epoch 8 | batch 3300/7127 | avg_loss=1.6843 | avg_top1=0.4412
#   [train] epoch 8 | batch 3600/7127 | avg_loss=1.6824 | avg_top1=0.4411
#   [train] epoch 8 | batch 3900/7127 | avg_loss=1.6821 | avg_top1=0.4410
#   [train] epoch 8 | batch 4200/7127 | avg_loss=1.6758 | avg_top1=0.4421
#   [train] epoch 8 | batch 4500/7127 | avg_loss=1.6680 | avg_top1=0.4447
#   [train] epoch 8 | batch 4800/7127 | avg_loss=1.6618 | avg_top1=0.4467
#   [train] epoch 8 | batch 5100/7127 | avg_loss=1.6560 | avg_top1=0.4480
#   [train] epoch 8 | batch 5400/7127 | avg_loss=1.6510 | avg_top1=0.4494
#   [train] epoch 8 | batch 5700/7127 | avg_loss=1.6468 | avg_top1=0.4505
#   [train] epoch 8 | batch 6000/7127 | avg_loss=1.6413 | avg_top1=0.4520
#   [train] epoch 8 | batch 6300/7127 | avg_loss=1.6386 | avg_top1=0.4533
#   [train] epoch 8 | batch 6600/7127 | avg_loss=1.6356 | avg_top1=0.4548
#   [train] epoch 8 | batch 6900/7127 | avg_loss=1.6323 | avg_top1=0.4564
#   [train] epoch 8 | batch 7127/7127 | avg_loss=1.6314 | avg_top1=0.4570
# Epoch 08 | fine-tune | lr=3.12e-06 | train_loss=1.6314, train_acc=0.4570 | val_loss=2.0482, val_acc=0.4282, val_top5=0.8534
#
# --- Starting epoch 9 ---
#   [train] epoch 9 | batch 300/7127 | avg_loss=1.6050 | avg_top1=0.4738
#   [train] epoch 9 | batch 600/7127 | avg_loss=1.6025 | avg_top1=0.4719
#   [train] epoch 9 | batch 900/7127 | avg_loss=1.5916 | avg_top1=0.4725
#   [train] epoch 9 | batch 1200/7127 | avg_loss=1.5946 | avg_top1=0.4729
#   [train] epoch 9 | batch 1500/7127 | avg_loss=1.5820 | avg_top1=0.4784
#   [train] epoch 9 | batch 1800/7127 | avg_loss=1.5866 | avg_top1=0.4733
#   [train] epoch 9 | batch 2100/7127 | avg_loss=1.5845 | avg_top1=0.4750
#   [train] epoch 9 | batch 2400/7127 | avg_loss=1.5854 | avg_top1=0.4754
#   [train] epoch 9 | batch 2700/7127 | avg_loss=1.5825 | avg_top1=0.4748
#   [train] epoch 9 | batch 3000/7127 | avg_loss=1.5704 | avg_top1=0.4780
#   [train] epoch 9 | batch 3300/7127 | avg_loss=1.5693 | avg_top1=0.4784
#   [train] epoch 9 | batch 3600/7127 | avg_loss=1.5651 | avg_top1=0.4782
#   [train] epoch 9 | batch 3900/7127 | avg_loss=1.5628 | avg_top1=0.4798
#   [train] epoch 9 | batch 4200/7127 | avg_loss=1.5587 | avg_top1=0.4799
#   [train] epoch 9 | batch 4500/7127 | avg_loss=1.5570 | avg_top1=0.4798
#   [train] epoch 9 | batch 4800/7127 | avg_loss=1.5536 | avg_top1=0.4816
#   [train] epoch 9 | batch 5100/7127 | avg_loss=1.5514 | avg_top1=0.4824
#   [train] epoch 9 | batch 5400/7127 | avg_loss=1.5474 | avg_top1=0.4830
#   [train] epoch 9 | batch 5700/7127 | avg_loss=1.5449 | avg_top1=0.4840
#   [train] epoch 9 | batch 6000/7127 | avg_loss=1.5418 | avg_top1=0.4846
#   [train] epoch 9 | batch 6300/7127 | avg_loss=1.5372 | avg_top1=0.4857
#   [train] epoch 9 | batch 6600/7127 | avg_loss=1.5349 | avg_top1=0.4865
#   [train] epoch 9 | batch 6900/7127 | avg_loss=1.5312 | avg_top1=0.4869
#   [train] epoch 9 | batch 7127/7127 | avg_loss=1.5292 | avg_top1=0.4878
# Epoch 09 | fine-tune | lr=4.00e-06 | train_loss=1.5292, train_acc=0.4878 | val_loss=1.8989, val_acc=0.4826, val_top5=0.8913
#
# --- Starting epoch 10 ---
#   [train] epoch 10 | batch 300/7127 | avg_loss=1.4840 | avg_top1=0.5121
#   [train] epoch 10 | batch 600/7127 | avg_loss=1.4748 | avg_top1=0.5135
#   [train] epoch 10 | batch 900/7127 | avg_loss=1.4767 | avg_top1=0.5140
#   [train] epoch 10 | batch 1200/7127 | avg_loss=1.4740 | avg_top1=0.5112
#   [train] epoch 10 | batch 1500/7127 | avg_loss=1.4754 | avg_top1=0.5070
#   [train] epoch 10 | batch 1800/7127 | avg_loss=1.4746 | avg_top1=0.5090
#   [train] epoch 10 | batch 2100/7127 | avg_loss=1.4688 | avg_top1=0.5080
#   [train] epoch 10 | batch 2400/7127 | avg_loss=1.4673 | avg_top1=0.5048
#   [train] epoch 10 | batch 2700/7127 | avg_loss=1.4625 | avg_top1=0.5078
#   [train] epoch 10 | batch 3000/7127 | avg_loss=1.4565 | avg_top1=0.5064
#   [train] epoch 10 | batch 3300/7127 | avg_loss=1.4545 | avg_top1=0.5047
#   [train] epoch 10 | batch 3600/7127 | avg_loss=1.4547 | avg_top1=0.5026
#   [train] epoch 10 | batch 3900/7127 | avg_loss=1.4539 | avg_top1=0.5050
#   [train] epoch 10 | batch 4200/7127 | avg_loss=1.4537 | avg_top1=0.5059
#   [train] epoch 10 | batch 4500/7127 | avg_loss=1.4505 | avg_top1=0.5062
#   [train] epoch 10 | batch 4800/7127 | avg_loss=1.4454 | avg_top1=0.5078
#   [train] epoch 10 | batch 5100/7127 | avg_loss=1.4416 | avg_top1=0.5074
#   [train] epoch 10 | batch 5400/7127 | avg_loss=1.4359 | avg_top1=0.5100
#   [train] epoch 10 | batch 5700/7127 | avg_loss=1.4331 | avg_top1=0.5105
#   [train] epoch 10 | batch 6000/7127 | avg_loss=1.4298 | avg_top1=0.5116
#   [train] epoch 10 | batch 6300/7127 | avg_loss=1.4292 | avg_top1=0.5118
#   [train] epoch 10 | batch 6600/7127 | avg_loss=1.4256 | avg_top1=0.5141
#   [train] epoch 10 | batch 6900/7127 | avg_loss=1.4239 | avg_top1=0.5153
#   [train] epoch 10 | batch 7127/7127 | avg_loss=1.4225 | avg_top1=0.5159
# Epoch 10 | fine-tune | lr=4.00e-06 | train_loss=1.4225, train_acc=0.5159 | val_loss=1.7728, val_acc=0.5289, val_top5=0.9168
#
# --- Starting epoch 11 ---
#   [train] epoch 11 | batch 300/7127 | avg_loss=1.3260 | avg_top1=0.5396
#   [train] epoch 11 | batch 600/7127 | avg_loss=1.3323 | avg_top1=0.5308
#   [train] epoch 11 | batch 900/7127 | avg_loss=1.3465 | avg_top1=0.5318
#   [train] epoch 11 | batch 1200/7127 | avg_loss=1.3503 | avg_top1=0.5322
#   [train] epoch 11 | batch 1500/7127 | avg_loss=1.3486 | avg_top1=0.5283
#   [train] epoch 11 | batch 1800/7127 | avg_loss=1.3500 | avg_top1=0.5294
#   [train] epoch 11 | batch 2100/7127 | avg_loss=1.3502 | avg_top1=0.5263
#   [train] epoch 11 | batch 2400/7127 | avg_loss=1.3439 | avg_top1=0.5273
#   [train] epoch 11 | batch 2700/7127 | avg_loss=1.3488 | avg_top1=0.5232
#   [train] epoch 11 | batch 3000/7127 | avg_loss=1.3460 | avg_top1=0.5264
#   [train] epoch 11 | batch 3300/7127 | avg_loss=1.3417 | avg_top1=0.5285
#   [train] epoch 11 | batch 3600/7127 | avg_loss=1.3414 | avg_top1=0.5308
#   [train] epoch 11 | batch 3900/7127 | avg_loss=1.3358 | avg_top1=0.5306
#   [train] epoch 11 | batch 4200/7127 | avg_loss=1.3364 | avg_top1=0.5312
#   [train] epoch 11 | batch 4500/7127 | avg_loss=1.3351 | avg_top1=0.5304
#   [train] epoch 11 | batch 4800/7127 | avg_loss=1.3338 | avg_top1=0.5310
#   [train] epoch 11 | batch 5100/7127 | avg_loss=1.3326 | avg_top1=0.5312
#   [train] epoch 11 | batch 5400/7127 | avg_loss=1.3311 | avg_top1=0.5326
#   [train] epoch 11 | batch 5700/7127 | avg_loss=1.3271 | avg_top1=0.5332
#   [train] epoch 11 | batch 6000/7127 | avg_loss=1.3258 | avg_top1=0.5339
#   [train] epoch 11 | batch 6300/7127 | avg_loss=1.3240 | avg_top1=0.5346
#   [train] epoch 11 | batch 6600/7127 | avg_loss=1.3215 | avg_top1=0.5354
#   [train] epoch 11 | batch 6900/7127 | avg_loss=1.3183 | avg_top1=0.5372
#   [train] epoch 11 | batch 7127/7127 | avg_loss=1.3178 | avg_top1=0.5367
# Epoch 11 | fine-tune | lr=3.99e-06 | train_loss=1.3178, train_acc=0.5367 | val_loss=1.6696, val_acc=0.5669, val_top5=0.9343
#
# --- Starting epoch 12 ---
#   [train] epoch 12 | batch 300/7127 | avg_loss=1.2440 | avg_top1=0.5767
#   [train] epoch 12 | batch 600/7127 | avg_loss=1.2454 | avg_top1=0.5752
#   [train] epoch 12 | batch 900/7127 | avg_loss=1.2478 | avg_top1=0.5737
#   [train] epoch 12 | batch 1200/7127 | avg_loss=1.2485 | avg_top1=0.5658
#   [train] epoch 12 | batch 1500/7127 | avg_loss=1.2540 | avg_top1=0.5677
#   [train] epoch 12 | batch 1800/7127 | avg_loss=1.2497 | avg_top1=0.5684
#   [train] epoch 12 | batch 2100/7127 | avg_loss=1.2469 | avg_top1=0.5668
#   [train] epoch 12 | batch 2400/7127 | avg_loss=1.2478 | avg_top1=0.5655
#   [train] epoch 12 | batch 2700/7127 | avg_loss=1.2512 | avg_top1=0.5615
#   [train] epoch 12 | batch 3000/7127 | avg_loss=1.2496 | avg_top1=0.5609
#   [train] epoch 12 | batch 3300/7127 | avg_loss=1.2494 | avg_top1=0.5636
#   [train] epoch 12 | batch 3600/7127 | avg_loss=1.2516 | avg_top1=0.5650
#   [train] epoch 12 | batch 3900/7127 | avg_loss=1.2495 | avg_top1=0.5660
#   [train] epoch 12 | batch 4200/7127 | avg_loss=1.2457 | avg_top1=0.5674
#   [train] epoch 12 | batch 4500/7127 | avg_loss=1.2416 | avg_top1=0.5673
#   [train] epoch 12 | batch 4800/7127 | avg_loss=1.2433 | avg_top1=0.5665
#   [train] epoch 12 | batch 5100/7127 | avg_loss=1.2431 | avg_top1=0.5670
#   [train] epoch 12 | batch 5400/7127 | avg_loss=1.2412 | avg_top1=0.5672
#   [train] epoch 12 | batch 5700/7127 | avg_loss=1.2387 | avg_top1=0.5673
#   [train] epoch 12 | batch 6000/7127 | avg_loss=1.2352 | avg_top1=0.5683
#   [train] epoch 12 | batch 6300/7127 | avg_loss=1.2337 | avg_top1=0.5683
#   [train] epoch 12 | batch 6600/7127 | avg_loss=1.2362 | avg_top1=0.5674
#   [train] epoch 12 | batch 6900/7127 | avg_loss=1.2347 | avg_top1=0.5683
#   [train] epoch 12 | batch 7127/7127 | avg_loss=1.2355 | avg_top1=0.5679
# Epoch 12 | fine-tune | lr=3.97e-06 | train_loss=1.2355, train_acc=0.5679 | val_loss=1.5863, val_acc=0.5997, val_top5=0.9468
#
# --- Starting epoch 13 ---
#   [train] epoch 13 | batch 300/7127 | avg_loss=1.2178 | avg_top1=0.5754
#   [train] epoch 13 | batch 600/7127 | avg_loss=1.1935 | avg_top1=0.5727
#   [train] epoch 13 | batch 900/7127 | avg_loss=1.1808 | avg_top1=0.5796
#   [train] epoch 13 | batch 1200/7127 | avg_loss=1.1781 | avg_top1=0.5735
#   [train] epoch 13 | batch 1500/7127 | avg_loss=1.1906 | avg_top1=0.5665
#   [train] epoch 13 | batch 1800/7127 | avg_loss=1.1837 | avg_top1=0.5708
#   [train] epoch 13 | batch 2100/7127 | avg_loss=1.1806 | avg_top1=0.5698
#   [train] epoch 13 | batch 2400/7127 | avg_loss=1.1831 | avg_top1=0.5698
#   [train] epoch 13 | batch 2700/7127 | avg_loss=1.1844 | avg_top1=0.5691
#   [train] epoch 13 | batch 3000/7127 | avg_loss=1.1860 | avg_top1=0.5694
#   [train] epoch 13 | batch 3300/7127 | avg_loss=1.1826 | avg_top1=0.5710
#   [train] epoch 13 | batch 3600/7127 | avg_loss=1.1826 | avg_top1=0.5722
#   [train] epoch 13 | batch 3900/7127 | avg_loss=1.1805 | avg_top1=0.5713
#   [train] epoch 13 | batch 4200/7127 | avg_loss=1.1778 | avg_top1=0.5729
#   [train] epoch 13 | batch 4500/7127 | avg_loss=1.1757 | avg_top1=0.5735
#   [train] epoch 13 | batch 4800/7127 | avg_loss=1.1742 | avg_top1=0.5736
#   [train] epoch 13 | batch 5100/7127 | avg_loss=1.1705 | avg_top1=0.5750
#   [train] epoch 13 | batch 5400/7127 | avg_loss=1.1712 | avg_top1=0.5757
#   [train] epoch 13 | batch 5700/7127 | avg_loss=1.1695 | avg_top1=0.5771
#   [train] epoch 13 | batch 6000/7127 | avg_loss=1.1697 | avg_top1=0.5777
#   [train] epoch 13 | batch 6300/7127 | avg_loss=1.1681 | avg_top1=0.5771
#   [train] epoch 13 | batch 6600/7127 | avg_loss=1.1650 | avg_top1=0.5765
#   [train] epoch 13 | batch 6900/7127 | avg_loss=1.1640 | avg_top1=0.5772
#   [train] epoch 13 | batch 7127/7127 | avg_loss=1.1645 | avg_top1=0.5774
# Epoch 13 | fine-tune | lr=3.94e-06 | train_loss=1.1645, train_acc=0.5774 | val_loss=1.5202, val_acc=0.6280, val_top5=0.9553
#
# --- Starting epoch 14 ---
#   [train] epoch 14 | batch 300/7127 | avg_loss=1.1442 | avg_top1=0.6100
#   [train] epoch 14 | batch 600/7127 | avg_loss=1.1393 | avg_top1=0.6071
#   [train] epoch 14 | batch 900/7127 | avg_loss=1.1267 | avg_top1=0.6015
#   [train] epoch 14 | batch 1200/7127 | avg_loss=1.1319 | avg_top1=0.5992
#   [train] epoch 14 | batch 1500/7127 | avg_loss=1.1306 | avg_top1=0.5966
#   [train] epoch 14 | batch 1800/7127 | avg_loss=1.1347 | avg_top1=0.5956
#   [train] epoch 14 | batch 2100/7127 | avg_loss=1.1315 | avg_top1=0.5937
#   [train] epoch 14 | batch 2400/7127 | avg_loss=1.1319 | avg_top1=0.5928
#   [train] epoch 14 | batch 2700/7127 | avg_loss=1.1352 | avg_top1=0.5895
#   [train] epoch 14 | batch 3000/7127 | avg_loss=1.1323 | avg_top1=0.5867
#   [train] epoch 14 | batch 3300/7127 | avg_loss=1.1306 | avg_top1=0.5857
#   [train] epoch 14 | batch 3600/7127 | avg_loss=1.1306 | avg_top1=0.5869
#   [train] epoch 14 | batch 3900/7127 | avg_loss=1.1277 | avg_top1=0.5866
#   [train] epoch 14 | batch 4200/7127 | avg_loss=1.1267 | avg_top1=0.5844
#   [train] epoch 14 | batch 4500/7127 | avg_loss=1.1286 | avg_top1=0.5858
#   [train] epoch 14 | batch 4800/7127 | avg_loss=1.1254 | avg_top1=0.5861
#   [train] epoch 14 | batch 5100/7127 | avg_loss=1.1230 | avg_top1=0.5879
#   [train] epoch 14 | batch 5400/7127 | avg_loss=1.1219 | avg_top1=0.5891
#   [train] epoch 14 | batch 5700/7127 | avg_loss=1.1205 | avg_top1=0.5887
#   [train] epoch 14 | batch 6000/7127 | avg_loss=1.1193 | avg_top1=0.5905
#   [train] epoch 14 | batch 6300/7127 | avg_loss=1.1197 | avg_top1=0.5907
#   [train] epoch 14 | batch 6600/7127 | avg_loss=1.1182 | avg_top1=0.5914
#   [train] epoch 14 | batch 6900/7127 | avg_loss=1.1175 | avg_top1=0.5902
#   [train] epoch 14 | batch 7127/7127 | avg_loss=1.1174 | avg_top1=0.5896
# Epoch 14 | fine-tune | lr=3.91e-06 | train_loss=1.1174, train_acc=0.5896 | val_loss=1.4692, val_acc=0.6517, val_top5=0.9608
#
# --- Starting epoch 15 ---
#   [train] epoch 15 | batch 300/7127 | avg_loss=1.0784 | avg_top1=0.6125
#   [train] epoch 15 | batch 600/7127 | avg_loss=1.0770 | avg_top1=0.6233
#   [train] epoch 15 | batch 900/7127 | avg_loss=1.0776 | avg_top1=0.6175
#   [train] epoch 15 | batch 1200/7127 | avg_loss=1.0769 | avg_top1=0.6143
#   [train] epoch 15 | batch 1500/7127 | avg_loss=1.0662 | avg_top1=0.6069
#   [train] epoch 15 | batch 1800/7127 | avg_loss=1.0689 | avg_top1=0.6060
#   [train] epoch 15 | batch 2100/7127 | avg_loss=1.0694 | avg_top1=0.6069
#   [train] epoch 15 | batch 2400/7127 | avg_loss=1.0670 | avg_top1=0.6095
#   [train] epoch 15 | batch 2700/7127 | avg_loss=1.0684 | avg_top1=0.6078
#   [train] epoch 15 | batch 3000/7127 | avg_loss=1.0704 | avg_top1=0.6058
#   [train] epoch 15 | batch 3300/7127 | avg_loss=1.0685 | avg_top1=0.6074
#   [train] epoch 15 | batch 3600/7127 | avg_loss=1.0696 | avg_top1=0.6047
#   [train] epoch 15 | batch 3900/7127 | avg_loss=1.0704 | avg_top1=0.6031
#   [train] epoch 15 | batch 4200/7127 | avg_loss=1.0731 | avg_top1=0.6016
#   [train] epoch 15 | batch 4500/7127 | avg_loss=1.0719 | avg_top1=0.6034
#   [train] epoch 15 | batch 4800/7127 | avg_loss=1.0692 | avg_top1=0.6039
#   [train] epoch 15 | batch 5100/7127 | avg_loss=1.0731 | avg_top1=0.6006
#   [train] epoch 15 | batch 5400/7127 | avg_loss=1.0717 | avg_top1=0.6008
#   [train] epoch 15 | batch 5700/7127 | avg_loss=1.0718 | avg_top1=0.6015
#   [train] epoch 15 | batch 6000/7127 | avg_loss=1.0729 | avg_top1=0.6018
#   [train] epoch 15 | batch 6300/7127 | avg_loss=1.0726 | avg_top1=0.6006
#   [train] epoch 15 | batch 6600/7127 | avg_loss=1.0701 | avg_top1=0.6012
#   [train] epoch 15 | batch 6900/7127 | avg_loss=1.0683 | avg_top1=0.6019
#   [train] epoch 15 | batch 7127/7127 | avg_loss=1.0670 | avg_top1=0.6028
# Epoch 15 | fine-tune | lr=3.87e-06 | train_loss=1.0670, train_acc=0.6028 | val_loss=1.4309, val_acc=0.6699, val_top5=0.9659
#
# --- Starting epoch 16 ---
#   [train] epoch 16 | batch 300/7127 | avg_loss=1.0164 | avg_top1=0.6262
#   [train] epoch 16 | batch 600/7127 | avg_loss=1.0125 | avg_top1=0.6302
#   [train] epoch 16 | batch 900/7127 | avg_loss=1.0269 | avg_top1=0.6238
#   [train] epoch 16 | batch 1200/7127 | avg_loss=1.0269 | avg_top1=0.6210
#   [train] epoch 16 | batch 1500/7127 | avg_loss=1.0257 | avg_top1=0.6185
#   [train] epoch 16 | batch 1800/7127 | avg_loss=1.0257 | avg_top1=0.6153
#   [train] epoch 16 | batch 2100/7127 | avg_loss=1.0152 | avg_top1=0.6149
#   [train] epoch 16 | batch 2400/7127 | avg_loss=1.0169 | avg_top1=0.6174
#   [train] epoch 16 | batch 2700/7127 | avg_loss=1.0165 | avg_top1=0.6179
#   [train] epoch 16 | batch 3000/7127 | avg_loss=1.0149 | avg_top1=0.6175
#   [train] epoch 16 | batch 3300/7127 | avg_loss=1.0197 | avg_top1=0.6151
#   [train] epoch 16 | batch 3600/7127 | avg_loss=1.0202 | avg_top1=0.6188
#   [train] epoch 16 | batch 3900/7127 | avg_loss=1.0244 | avg_top1=0.6178
#   [train] epoch 16 | batch 4200/7127 | avg_loss=1.0222 | avg_top1=0.6171
#   [train] epoch 16 | batch 4500/7127 | avg_loss=1.0204 | avg_top1=0.6186
#   [train] epoch 16 | batch 4800/7127 | avg_loss=1.0194 | avg_top1=0.6185
#   [train] epoch 16 | batch 5100/7127 | avg_loss=1.0167 | avg_top1=0.6179
#   [train] epoch 16 | batch 5400/7127 | avg_loss=1.0176 | avg_top1=0.6184
#   [train] epoch 16 | batch 5700/7127 | avg_loss=1.0159 | avg_top1=0.6181
#   [train] epoch 16 | batch 6000/7127 | avg_loss=1.0161 | avg_top1=0.6176
#   [train] epoch 16 | batch 6300/7127 | avg_loss=1.0165 | avg_top1=0.6168
#   [train] epoch 16 | batch 6600/7127 | avg_loss=1.0167 | avg_top1=0.6163
#   [train] epoch 16 | batch 6900/7127 | avg_loss=1.0156 | avg_top1=0.6172
#   [train] epoch 16 | batch 7127/7127 | avg_loss=1.0139 | avg_top1=0.6172
# Epoch 16 | fine-tune | lr=3.82e-06 | train_loss=1.0139, train_acc=0.6172 | val_loss=1.4032, val_acc=0.6860, val_top5=0.9698
#
# --- Starting epoch 17 ---
#   [train] epoch 17 | batch 300/7127 | avg_loss=0.9331 | avg_top1=0.6379
#   [train] epoch 17 | batch 600/7127 | avg_loss=0.9810 | avg_top1=0.6277
#   [train] epoch 17 | batch 900/7127 | avg_loss=0.9832 | avg_top1=0.6224
#   [train] epoch 17 | batch 1200/7127 | avg_loss=0.9875 | avg_top1=0.6231
#   [train] epoch 17 | batch 1500/7127 | avg_loss=0.9871 | avg_top1=0.6271
#   [train] epoch 17 | batch 1800/7127 | avg_loss=0.9923 | avg_top1=0.6222
#   [train] epoch 17 | batch 2100/7127 | avg_loss=0.9917 | avg_top1=0.6171
#   [train] epoch 17 | batch 2400/7127 | avg_loss=0.9943 | avg_top1=0.6148
#   [train] epoch 17 | batch 2700/7127 | avg_loss=0.9969 | avg_top1=0.6143
#   [train] epoch 17 | batch 3000/7127 | avg_loss=0.9954 | avg_top1=0.6149
#   [train] epoch 17 | batch 3300/7127 | avg_loss=0.9954 | avg_top1=0.6180
#   [train] epoch 17 | batch 3600/7127 | avg_loss=0.9904 | avg_top1=0.6195
#   [train] epoch 17 | batch 3900/7127 | avg_loss=0.9877 | avg_top1=0.6215
#   [train] epoch 17 | batch 4200/7127 | avg_loss=0.9874 | avg_top1=0.6215
#   [train] epoch 17 | batch 4500/7127 | avg_loss=0.9855 | avg_top1=0.6239
#   [train] epoch 17 | batch 4800/7127 | avg_loss=0.9858 | avg_top1=0.6227
#   [train] epoch 17 | batch 5100/7127 | avg_loss=0.9882 | avg_top1=0.6221
#   [train] epoch 17 | batch 5400/7127 | avg_loss=0.9884 | avg_top1=0.6223
#   [train] epoch 17 | batch 5700/7127 | avg_loss=0.9879 | avg_top1=0.6219
#   [train] epoch 17 | batch 6000/7127 | avg_loss=0.9880 | avg_top1=0.6228
#   [train] epoch 17 | batch 6300/7127 | avg_loss=0.9871 | avg_top1=0.6234
#   [train] epoch 17 | batch 6600/7127 | avg_loss=0.9882 | avg_top1=0.6227
#   [train] epoch 17 | batch 6900/7127 | avg_loss=0.9902 | avg_top1=0.6229
#   [train] epoch 17 | batch 7127/7127 | avg_loss=0.9905 | avg_top1=0.6232
# Epoch 17 | fine-tune | lr=3.77e-06 | train_loss=0.9905, train_acc=0.6232 | val_loss=1.3855, val_acc=0.6993, val_top5=0.9722
#
# --- Starting epoch 18 ---
#   [train] epoch 18 | batch 300/7127 | avg_loss=0.9602 | avg_top1=0.6379
#   [train] epoch 18 | batch 600/7127 | avg_loss=0.9642 | avg_top1=0.6417
#   [train] epoch 18 | batch 900/7127 | avg_loss=0.9743 | avg_top1=0.6356
#   [train] epoch 18 | batch 1200/7127 | avg_loss=0.9729 | avg_top1=0.6297
#   [train] epoch 18 | batch 1500/7127 | avg_loss=0.9656 | avg_top1=0.6273
#   [train] epoch 18 | batch 1800/7127 | avg_loss=0.9656 | avg_top1=0.6235
#   [train] epoch 18 | batch 2100/7127 | avg_loss=0.9656 | avg_top1=0.6243
#   [train] epoch 18 | batch 2400/7127 | avg_loss=0.9677 | avg_top1=0.6218
#   [train] epoch 18 | batch 2700/7127 | avg_loss=0.9676 | avg_top1=0.6227
#   [train] epoch 18 | batch 3000/7127 | avg_loss=0.9632 | avg_top1=0.6248
#   [train] epoch 18 | batch 3300/7127 | avg_loss=0.9594 | avg_top1=0.6266
#   [train] epoch 18 | batch 3600/7127 | avg_loss=0.9603 | avg_top1=0.6266
#   [train] epoch 18 | batch 3900/7127 | avg_loss=0.9581 | avg_top1=0.6268
#   [train] epoch 18 | batch 4200/7127 | avg_loss=0.9597 | avg_top1=0.6257
#   [train] epoch 18 | batch 4500/7127 | avg_loss=0.9589 | avg_top1=0.6260
#   [train] epoch 18 | batch 4800/7127 | avg_loss=0.9548 | avg_top1=0.6251
#   [train] epoch 18 | batch 5100/7127 | avg_loss=0.9574 | avg_top1=0.6238
#   [train] epoch 18 | batch 5400/7127 | avg_loss=0.9557 | avg_top1=0.6248
#   [train] epoch 18 | batch 5700/7127 | avg_loss=0.9541 | avg_top1=0.6245
#   [train] epoch 18 | batch 6000/7127 | avg_loss=0.9542 | avg_top1=0.6240
#   [train] epoch 18 | batch 6300/7127 | avg_loss=0.9532 | avg_top1=0.6256
#   [train] epoch 18 | batch 6600/7127 | avg_loss=0.9515 | avg_top1=0.6254
#   [train] epoch 18 | batch 6900/7127 | avg_loss=0.9502 | avg_top1=0.6243
#   [train] epoch 18 | batch 7127/7127 | avg_loss=0.9496 | avg_top1=0.6250
# Epoch 18 | fine-tune | lr=3.71e-06 | train_loss=0.9496, train_acc=0.6250 | val_loss=1.3752, val_acc=0.7105, val_top5=0.9739
#
# --- Starting epoch 19 ---
#   [train] epoch 19 | batch 300/7127 | avg_loss=0.9777 | avg_top1=0.6446
#   [train] epoch 19 | batch 600/7127 | avg_loss=0.9527 | avg_top1=0.6473
#   [train] epoch 19 | batch 900/7127 | avg_loss=0.9522 | avg_top1=0.6424
#   [train] epoch 19 | batch 1200/7127 | avg_loss=0.9542 | avg_top1=0.6368
#   [train] epoch 19 | batch 1500/7127 | avg_loss=0.9548 | avg_top1=0.6343
#   [train] epoch 19 | batch 1800/7127 | avg_loss=0.9538 | avg_top1=0.6333
#   [train] epoch 19 | batch 2100/7127 | avg_loss=0.9543 | avg_top1=0.6323
#   [train] epoch 19 | batch 2400/7127 | avg_loss=0.9496 | avg_top1=0.6335
#   [train] epoch 19 | batch 2700/7127 | avg_loss=0.9462 | avg_top1=0.6336
#   [train] epoch 19 | batch 3000/7127 | avg_loss=0.9431 | avg_top1=0.6361
#   [train] epoch 19 | batch 3300/7127 | avg_loss=0.9400 | avg_top1=0.6364
#   [train] epoch 19 | batch 3600/7127 | avg_loss=0.9367 | avg_top1=0.6381
#   [train] epoch 19 | batch 3900/7127 | avg_loss=0.9405 | avg_top1=0.6354
#   [train] epoch 19 | batch 4200/7127 | avg_loss=0.9388 | avg_top1=0.6353
#   [train] epoch 19 | batch 4500/7127 | avg_loss=0.9373 | avg_top1=0.6349
#   [train] epoch 19 | batch 4800/7127 | avg_loss=0.9373 | avg_top1=0.6331
#   [train] epoch 19 | batch 5100/7127 | avg_loss=0.9377 | avg_top1=0.6349
#   [train] epoch 19 | batch 5400/7127 | avg_loss=0.9391 | avg_top1=0.6337
#   [train] epoch 19 | batch 5700/7127 | avg_loss=0.9392 | avg_top1=0.6335
#   [train] epoch 19 | batch 6000/7127 | avg_loss=0.9363 | avg_top1=0.6342
#   [train] epoch 19 | batch 6300/7127 | avg_loss=0.9340 | avg_top1=0.6341
#   [train] epoch 19 | batch 6600/7127 | avg_loss=0.9328 | avg_top1=0.6350
#   [train] epoch 19 | batch 6900/7127 | avg_loss=0.9337 | avg_top1=0.6344
#   [train] epoch 19 | batch 7127/7127 | avg_loss=0.9333 | avg_top1=0.6335
# Epoch 19 | fine-tune | lr=3.65e-06 | train_loss=0.9333, train_acc=0.6335 | val_loss=1.3699, val_acc=0.7189, val_top5=0.9751
#
# --- Starting epoch 20 ---
#   [train] epoch 20 | batch 300/7127 | avg_loss=0.9612 | avg_top1=0.6458
#   [train] epoch 20 | batch 600/7127 | avg_loss=0.9334 | avg_top1=0.6404
#   [train] epoch 20 | batch 900/7127 | avg_loss=0.9164 | avg_top1=0.6561
#   [train] epoch 20 | batch 1200/7127 | avg_loss=0.9201 | avg_top1=0.6497
#   [train] epoch 20 | batch 1500/7127 | avg_loss=0.9113 | avg_top1=0.6510
#   [train] epoch 20 | batch 1800/7127 | avg_loss=0.9062 | avg_top1=0.6474
#   [train] epoch 20 | batch 2100/7127 | avg_loss=0.9057 | avg_top1=0.6479
#   [train] epoch 20 | batch 2400/7127 | avg_loss=0.9086 | avg_top1=0.6477
#   [train] epoch 20 | batch 2700/7127 | avg_loss=0.9100 | avg_top1=0.6467
#   [train] epoch 20 | batch 3000/7127 | avg_loss=0.9060 | avg_top1=0.6455
#   [train] epoch 20 | batch 3300/7127 | avg_loss=0.9092 | avg_top1=0.6463
#   [train] epoch 20 | batch 3600/7127 | avg_loss=0.9114 | avg_top1=0.6448
#   [train] epoch 20 | batch 3900/7127 | avg_loss=0.9115 | avg_top1=0.6437
#   [train] epoch 20 | batch 4200/7127 | avg_loss=0.9065 | avg_top1=0.6443
#   [train] epoch 20 | batch 4500/7127 | avg_loss=0.9052 | avg_top1=0.6430
#   [train] epoch 20 | batch 4800/7127 | avg_loss=0.9053 | avg_top1=0.6438
#   [train] epoch 20 | batch 5100/7127 | avg_loss=0.9059 | avg_top1=0.6432
#   [train] epoch 20 | batch 5400/7127 | avg_loss=0.9039 | avg_top1=0.6433
#   [train] epoch 20 | batch 5700/7127 | avg_loss=0.9044 | avg_top1=0.6432
#   [train] epoch 20 | batch 6000/7127 | avg_loss=0.9024 | avg_top1=0.6444
#   [train] epoch 20 | batch 6300/7127 | avg_loss=0.9011 | avg_top1=0.6441
#   [train] epoch 20 | batch 6600/7127 | avg_loss=0.9022 | avg_top1=0.6430
#   [train] epoch 20 | batch 6900/7127 | avg_loss=0.9018 | avg_top1=0.6448
#   [train] epoch 20 | batch 7127/7127 | avg_loss=0.9033 | avg_top1=0.6432
# Epoch 20 | fine-tune | lr=3.57e-06 | train_loss=0.9033, train_acc=0.6432 | val_loss=1.3693, val_acc=0.7261, val_top5=0.9765
#
# --- Starting epoch 21 ---
#   [train] epoch 21 | batch 300/7127 | avg_loss=0.8692 | avg_top1=0.6454
#   [train] epoch 21 | batch 600/7127 | avg_loss=0.8950 | avg_top1=0.6431
#   [train] epoch 21 | batch 900/7127 | avg_loss=0.8898 | avg_top1=0.6346
#   [train] epoch 21 | batch 1200/7127 | avg_loss=0.8865 | avg_top1=0.6357
#   [train] epoch 21 | batch 1500/7127 | avg_loss=0.8859 | avg_top1=0.6405
#   [train] epoch 21 | batch 1800/7127 | avg_loss=0.8811 | avg_top1=0.6440
#   [train] epoch 21 | batch 2100/7127 | avg_loss=0.8793 | avg_top1=0.6490
#   [train] epoch 21 | batch 2400/7127 | avg_loss=0.8818 | avg_top1=0.6485
#   [train] epoch 21 | batch 2700/7127 | avg_loss=0.8836 | avg_top1=0.6498
#   [train] epoch 21 | batch 3000/7127 | avg_loss=0.8837 | avg_top1=0.6487
#   [train] epoch 21 | batch 3300/7127 | avg_loss=0.8799 | avg_top1=0.6511
#   [train] epoch 21 | batch 3600/7127 | avg_loss=0.8793 | avg_top1=0.6517
#   [train] epoch 21 | batch 3900/7127 | avg_loss=0.8800 | avg_top1=0.6503
#   [train] epoch 21 | batch 4200/7127 | avg_loss=0.8810 | avg_top1=0.6496
#   [train] epoch 21 | batch 4500/7127 | avg_loss=0.8789 | avg_top1=0.6483
#   [train] epoch 21 | batch 4800/7127 | avg_loss=0.8805 | avg_top1=0.6473
#   [train] epoch 21 | batch 5100/7127 | avg_loss=0.8801 | avg_top1=0.6469
#   [train] epoch 21 | batch 5400/7127 | avg_loss=0.8800 | avg_top1=0.6472
#   [train] epoch 21 | batch 5700/7127 | avg_loss=0.8772 | avg_top1=0.6475
#   [train] epoch 21 | batch 6000/7127 | avg_loss=0.8778 | avg_top1=0.6486
#   [train] epoch 21 | batch 6300/7127 | avg_loss=0.8791 | avg_top1=0.6478
#   [train] epoch 21 | batch 6600/7127 | avg_loss=0.8804 | avg_top1=0.6471
#   [train] epoch 21 | batch 6900/7127 | avg_loss=0.8796 | avg_top1=0.6468
#   [train] epoch 21 | batch 7127/7127 | avg_loss=0.8782 | avg_top1=0.6469
# Epoch 21 | fine-tune | lr=3.50e-06 | train_loss=0.8782, train_acc=0.6469 | val_loss=1.3724, val_acc=0.7299, val_top5=0.9767
#
# --- Starting epoch 22 ---
#   [train] epoch 22 | batch 300/7127 | avg_loss=0.8645 | avg_top1=0.6408
#   [train] epoch 22 | batch 600/7127 | avg_loss=0.8551 | avg_top1=0.6615
#   [train] epoch 22 | batch 900/7127 | avg_loss=0.8708 | avg_top1=0.6478
#   [train] epoch 22 | batch 1200/7127 | avg_loss=0.8721 | avg_top1=0.6458
#   [train] epoch 22 | batch 1500/7127 | avg_loss=0.8699 | avg_top1=0.6454
#   [train] epoch 22 | batch 1800/7127 | avg_loss=0.8609 | avg_top1=0.6517
#   [train] epoch 22 | batch 2100/7127 | avg_loss=0.8659 | avg_top1=0.6488
#   [train] epoch 22 | batch 2400/7127 | avg_loss=0.8631 | avg_top1=0.6526
#   [train] epoch 22 | batch 2700/7127 | avg_loss=0.8616 | avg_top1=0.6510
#   [train] epoch 22 | batch 3000/7127 | avg_loss=0.8612 | avg_top1=0.6508
#   [train] epoch 22 | batch 3300/7127 | avg_loss=0.8567 | avg_top1=0.6516
#   [train] epoch 22 | batch 3600/7127 | avg_loss=0.8535 | avg_top1=0.6537
#   [train] epoch 22 | batch 3900/7127 | avg_loss=0.8534 | avg_top1=0.6533
#   [train] epoch 22 | batch 4200/7127 | avg_loss=0.8533 | avg_top1=0.6521
#   [train] epoch 22 | batch 4500/7127 | avg_loss=0.8498 | avg_top1=0.6536
#   [train] epoch 22 | batch 4800/7127 | avg_loss=0.8481 | avg_top1=0.6542
#   [train] epoch 22 | batch 5100/7127 | avg_loss=0.8494 | avg_top1=0.6543
#   [train] epoch 22 | batch 5400/7127 | avg_loss=0.8485 | avg_top1=0.6542
#   [train] epoch 22 | batch 5700/7127 | avg_loss=0.8474 | avg_top1=0.6543
#   [train] epoch 22 | batch 6000/7127 | avg_loss=0.8468 | avg_top1=0.6546
#   [train] epoch 22 | batch 6300/7127 | avg_loss=0.8465 | avg_top1=0.6543
#   [train] epoch 22 | batch 6600/7127 | avg_loss=0.8463 | avg_top1=0.6538
#   [train] epoch 22 | batch 6900/7127 | avg_loss=0.8456 | avg_top1=0.6542
#   [train] epoch 22 | batch 7127/7127 | avg_loss=0.8451 | avg_top1=0.6548
# Epoch 22 | fine-tune | lr=3.41e-06 | train_loss=0.8451, train_acc=0.6548 | val_loss=1.3776, val_acc=0.7345, val_top5=0.9778
#
# --- Starting epoch 23 ---
#   [train] epoch 23 | batch 300/7127 | avg_loss=0.8473 | avg_top1=0.6733
#   [train] epoch 23 | batch 600/7127 | avg_loss=0.8366 | avg_top1=0.6658
#   [train] epoch 23 | batch 900/7127 | avg_loss=0.8318 | avg_top1=0.6650
#   [train] epoch 23 | batch 1200/7127 | avg_loss=0.8436 | avg_top1=0.6659
#   [train] epoch 23 | batch 1500/7127 | avg_loss=0.8429 | avg_top1=0.6653
#   [train] epoch 23 | batch 1800/7127 | avg_loss=0.8415 | avg_top1=0.6610
#   [train] epoch 23 | batch 2100/7127 | avg_loss=0.8386 | avg_top1=0.6618
#   [train] epoch 23 | batch 2400/7127 | avg_loss=0.8413 | avg_top1=0.6596
#   [train] epoch 23 | batch 2700/7127 | avg_loss=0.8407 | avg_top1=0.6605
#   [train] epoch 23 | batch 3000/7127 | avg_loss=0.8364 | avg_top1=0.6619
#   [train] epoch 23 | batch 3300/7127 | avg_loss=0.8383 | avg_top1=0.6586
#   [train] epoch 23 | batch 3600/7127 | avg_loss=0.8369 | avg_top1=0.6579
#   [train] epoch 23 | batch 3900/7127 | avg_loss=0.8358 | avg_top1=0.6582
#   [train] epoch 23 | batch 4200/7127 | avg_loss=0.8345 | avg_top1=0.6582
#   [train] epoch 23 | batch 4500/7127 | avg_loss=0.8334 | avg_top1=0.6590
#   [train] epoch 23 | batch 4800/7127 | avg_loss=0.8325 | avg_top1=0.6620
#   [train] epoch 23 | batch 5100/7127 | avg_loss=0.8311 | avg_top1=0.6643
#   [train] epoch 23 | batch 5400/7127 | avg_loss=0.8295 | avg_top1=0.6653
#   [train] epoch 23 | batch 5700/7127 | avg_loss=0.8298 | avg_top1=0.6645
#   [train] epoch 23 | batch 6000/7127 | avg_loss=0.8292 | avg_top1=0.6633
#   [train] epoch 23 | batch 6300/7127 | avg_loss=0.8306 | avg_top1=0.6617
#   [train] epoch 23 | batch 6600/7127 | avg_loss=0.8286 | avg_top1=0.6617
#   [train] epoch 23 | batch 6900/7127 | avg_loss=0.8275 | avg_top1=0.6604
#   [train] epoch 23 | batch 7127/7127 | avg_loss=0.8279 | avg_top1=0.6613
# Epoch 23 | fine-tune | lr=3.33e-06 | train_loss=0.8279, train_acc=0.6613 | val_loss=1.3838, val_acc=0.7407, val_top5=0.9790
#
# --- Starting epoch 24 ---
#   [train] epoch 24 | batch 300/7127 | avg_loss=0.8006 | avg_top1=0.6554
#   [train] epoch 24 | batch 600/7127 | avg_loss=0.8034 | avg_top1=0.6660
#   [train] epoch 24 | batch 900/7127 | avg_loss=0.8159 | avg_top1=0.6613
#   [train] epoch 24 | batch 1200/7127 | avg_loss=0.8175 | avg_top1=0.6637
#   [train] epoch 24 | batch 1500/7127 | avg_loss=0.8213 | avg_top1=0.6629
#   [train] epoch 24 | batch 1800/7127 | avg_loss=0.8228 | avg_top1=0.6592
#   [train] epoch 24 | batch 2100/7127 | avg_loss=0.8199 | avg_top1=0.6585
#   [train] epoch 24 | batch 2400/7127 | avg_loss=0.8162 | avg_top1=0.6568
#   [train] epoch 24 | batch 2700/7127 | avg_loss=0.8140 | avg_top1=0.6581
#   [train] epoch 24 | batch 3000/7127 | avg_loss=0.8121 | avg_top1=0.6574
#   [train] epoch 24 | batch 3300/7127 | avg_loss=0.8095 | avg_top1=0.6576
#   [train] epoch 24 | batch 3600/7127 | avg_loss=0.8116 | avg_top1=0.6567
#   [train] epoch 24 | batch 3900/7127 | avg_loss=0.8156 | avg_top1=0.6576
#   [train] epoch 24 | batch 4200/7127 | avg_loss=0.8168 | avg_top1=0.6575
#   [train] epoch 24 | batch 4500/7127 | avg_loss=0.8178 | avg_top1=0.6554
#   [train] epoch 24 | batch 4800/7127 | avg_loss=0.8189 | avg_top1=0.6538
#   [train] epoch 24 | batch 5100/7127 | avg_loss=0.8182 | avg_top1=0.6543
#   [train] epoch 24 | batch 5400/7127 | avg_loss=0.8180 | avg_top1=0.6544
#   [train] epoch 24 | batch 5700/7127 | avg_loss=0.8188 | avg_top1=0.6542
#   [train] epoch 24 | batch 6000/7127 | avg_loss=0.8194 | avg_top1=0.6554
#   [train] epoch 24 | batch 6300/7127 | avg_loss=0.8180 | avg_top1=0.6565
#   [train] epoch 24 | batch 6600/7127 | avg_loss=0.8191 | avg_top1=0.6557
#   [train] epoch 24 | batch 6900/7127 | avg_loss=0.8181 | avg_top1=0.6559
#   [train] epoch 24 | batch 7127/7127 | avg_loss=0.8184 | avg_top1=0.6558
# Epoch 24 | fine-tune | lr=3.23e-06 | train_loss=0.8184, train_acc=0.6558 | val_loss=1.3914, val_acc=0.7444, val_top5=0.9790
#
# --- Starting epoch 25 ---
#   [train] epoch 25 | batch 300/7127 | avg_loss=0.7877 | avg_top1=0.6450
#   [train] epoch 25 | batch 600/7127 | avg_loss=0.7981 | avg_top1=0.6594
#   [train] epoch 25 | batch 900/7127 | avg_loss=0.8132 | avg_top1=0.6681
#   [train] epoch 25 | batch 1200/7127 | avg_loss=0.8069 | avg_top1=0.6679
#   [train] epoch 25 | batch 1500/7127 | avg_loss=0.7990 | avg_top1=0.6742
#   [train] epoch 25 | batch 1800/7127 | avg_loss=0.7907 | avg_top1=0.6696
#   [train] epoch 25 | batch 2100/7127 | avg_loss=0.7932 | avg_top1=0.6671
#   [train] epoch 25 | batch 2400/7127 | avg_loss=0.7978 | avg_top1=0.6660
#   [train] epoch 25 | batch 2700/7127 | avg_loss=0.7990 | avg_top1=0.6641
#   [train] epoch 25 | batch 3000/7127 | avg_loss=0.8011 | avg_top1=0.6660
#   [train] epoch 25 | batch 3300/7127 | avg_loss=0.8001 | avg_top1=0.6669
#   [train] epoch 25 | batch 3600/7127 | avg_loss=0.7997 | avg_top1=0.6667
#   [train] epoch 25 | batch 3900/7127 | avg_loss=0.7997 | avg_top1=0.6673
#   [train] epoch 25 | batch 4200/7127 | avg_loss=0.7975 | avg_top1=0.6678
#   [train] epoch 25 | batch 4500/7127 | avg_loss=0.7979 | avg_top1=0.6689
#   [train] epoch 25 | batch 4800/7127 | avg_loss=0.7980 | avg_top1=0.6671
#   [train] epoch 25 | batch 5100/7127 | avg_loss=0.7975 | avg_top1=0.6671
#   [train] epoch 25 | batch 5400/7127 | avg_loss=0.7963 | avg_top1=0.6670
#   [train] epoch 25 | batch 5700/7127 | avg_loss=0.7941 | avg_top1=0.6680
#   [train] epoch 25 | batch 6000/7127 | avg_loss=0.7934 | avg_top1=0.6675
#   [train] epoch 25 | batch 6300/7127 | avg_loss=0.7929 | avg_top1=0.6672
#   [train] epoch 25 | batch 6600/7127 | avg_loss=0.7924 | avg_top1=0.6688
#   [train] epoch 25 | batch 6900/7127 | avg_loss=0.7933 | avg_top1=0.6679
#   [train] epoch 25 | batch 7127/7127 | avg_loss=0.7928 | avg_top1=0.6672
# Epoch 25 | fine-tune | lr=3.14e-06 | train_loss=0.7928, train_acc=0.6672 | val_loss=1.3995, val_acc=0.7474, val_top5=0.9794
#
# --- Starting epoch 26 ---
#   [train] epoch 26 | batch 300/7127 | avg_loss=0.7985 | avg_top1=0.6504
#   [train] epoch 26 | batch 600/7127 | avg_loss=0.7839 | avg_top1=0.6694
#   [train] epoch 26 | batch 900/7127 | avg_loss=0.7847 | avg_top1=0.6587
#   [train] epoch 26 | batch 1200/7127 | avg_loss=0.7823 | avg_top1=0.6656
#   [train] epoch 26 | batch 1500/7127 | avg_loss=0.7779 | avg_top1=0.6700
#   [train] epoch 26 | batch 1800/7127 | avg_loss=0.7834 | avg_top1=0.6682
#   [train] epoch 26 | batch 2100/7127 | avg_loss=0.7807 | avg_top1=0.6740
# ...
#   [train] epoch 53 | batch 6900/7127 | avg_loss=0.5767 | avg_top1=0.7057
#   [train] epoch 53 | batch 7127/7127 | avg_loss=0.5759 | avg_top1=0.7065
# Epoch 53 | fine-tune | lr=2.29e-07 | train_loss=0.5759, train_acc=0.7065 | val_loss=1.5466, val_acc=0.7642, val_top5=0.9736
#
# --- Starting epoch 54 ---
#   [train] epoch 54 | batch 300/7127 | avg_loss=0.5612 | avg_top1=0.7179
#   [train] epoch 54 | batch 600/7127 | avg_loss=0.5646 | avg_top1=0.7123
#   [train] epoch 54 | batch 900/7127 | avg_loss=0.5732 | avg_top1=0.6951
#   [train] epoch 54 | batch 1200/7127 | avg_loss=0.5765 | avg_top1=0.7015
#   [train] epoch 54 | batch 1500/7127 | avg_loss=0.5748 | avg_top1=0.7027
#   [train] epoch 54 | batch 1800/7127 | avg_loss=0.5768 | avg_top1=0.7022
#   [train] epoch 54 | batch 2100/7127 | avg_loss=0.5762 | avg_top1=0.7032
#   [train] epoch 54 | batch 2400/7127 | avg_loss=0.5742 | avg_top1=0.7034
#   [train] epoch 54 | batch 2700/7127 | avg_loss=0.5742 | avg_top1=0.7056
#   [train] epoch 54 | batch 3000/7127 | avg_loss=0.5727 | avg_top1=0.7055
#   [train] epoch 54 | batch 3300/7127 | avg_loss=0.5732 | avg_top1=0.7050
#   [train] epoch 54 | batch 3600/7127 | avg_loss=0.5730 | avg_top1=0.7056
#   [train] epoch 54 | batch 3900/7127 | avg_loss=0.5739 | avg_top1=0.7047
#   [train] epoch 54 | batch 4200/7127 | avg_loss=0.5731 | avg_top1=0.7066
#   [train] epoch 54 | batch 4500/7127 | avg_loss=0.5731 | avg_top1=0.7073
#   [train] epoch 54 | batch 4800/7127 | avg_loss=0.5725 | avg_top1=0.7086
#   [train] epoch 54 | batch 5100/7127 | avg_loss=0.5740 | avg_top1=0.7066
#   [train] epoch 54 | batch 5400/7127 | avg_loss=0.5731 | avg_top1=0.7051
#   [train] epoch 54 | batch 5700/7127 | avg_loss=0.5738 | avg_top1=0.7027
#   [train] epoch 54 | batch 6000/7127 | avg_loss=0.5745 | avg_top1=0.7051
#   [train] epoch 54 | batch 6300/7127 | avg_loss=0.5752 | avg_top1=0.7040
#   [train] epoch 54 | batch 6600/7127 | avg_loss=0.5761 | avg_top1=0.7043
#   [train] epoch 54 | batch 6900/7127 | avg_loss=0.5752 | avg_top1=0.7045
#   [train] epoch 54 | batch 7127/7127 | avg_loss=0.5750 | avg_top1=0.7035
# Epoch 54 | fine-tune | lr=1.76e-07 | train_loss=0.5750, train_acc=0.7035 | val_loss=1.5469, val_acc=0.7638, val_top5=0.9731
#
# --- Starting epoch 55 ---
#   [train] epoch 55 | batch 300/7127 | avg_loss=0.5910 | avg_top1=0.7071
#   [train] epoch 55 | batch 600/7127 | avg_loss=0.5879 | avg_top1=0.7131
#   [train] epoch 55 | batch 900/7127 | avg_loss=0.5856 | avg_top1=0.7135
#   [train] epoch 55 | batch 1200/7127 | avg_loss=0.5846 | avg_top1=0.7124
#   [train] epoch 55 | batch 1500/7127 | avg_loss=0.5894 | avg_top1=0.7085
#   [train] epoch 55 | batch 1800/7127 | avg_loss=0.5906 | avg_top1=0.7058
#   [train] epoch 55 | batch 2100/7127 | avg_loss=0.5901 | avg_top1=0.7084
#   [train] epoch 55 | batch 2400/7127 | avg_loss=0.5894 | avg_top1=0.7064
#   [train] epoch 55 | batch 2700/7127 | avg_loss=0.5857 | avg_top1=0.7064
#   [train] epoch 55 | batch 3000/7127 | avg_loss=0.5855 | avg_top1=0.7073
#   [train] epoch 55 | batch 3300/7127 | avg_loss=0.5902 | avg_top1=0.7063
#   [train] epoch 55 | batch 3600/7127 | avg_loss=0.5925 | avg_top1=0.7054
#   [train] epoch 55 | batch 3900/7127 | avg_loss=0.5917 | avg_top1=0.7070
#   [train] epoch 55 | batch 4200/7127 | avg_loss=0.5908 | avg_top1=0.7070
#   [train] epoch 55 | batch 4500/7127 | avg_loss=0.5873 | avg_top1=0.7059
#   [train] epoch 55 | batch 4800/7127 | avg_loss=0.5864 | avg_top1=0.7052
#   [train] epoch 55 | batch 5100/7127 | avg_loss=0.5833 | avg_top1=0.7074
#   [train] epoch 55 | batch 5400/7127 | avg_loss=0.5825 | avg_top1=0.7067
#   [train] epoch 55 | batch 5700/7127 | avg_loss=0.5840 | avg_top1=0.7055
#   [train] epoch 55 | batch 6000/7127 | avg_loss=0.5838 | avg_top1=0.7066
#   [train] epoch 55 | batch 6300/7127 | avg_loss=0.5839 | avg_top1=0.7071
#   [train] epoch 55 | batch 6600/7127 | avg_loss=0.5839 | avg_top1=0.7073
#   [train] epoch 55 | batch 6900/7127 | avg_loss=0.5830 | avg_top1=0.7073
#   [train] epoch 55 | batch 7127/7127 | avg_loss=0.5823 | avg_top1=0.7070
# Epoch 55 | fine-tune | lr=1.30e-07 | train_loss=0.5823, train_acc=0.7070 | val_loss=1.5474, val_acc=0.7646, val_top5=0.9729
#
# --- Starting epoch 56 ---
#   [train] epoch 56 | batch 300/7127 | avg_loss=0.5677 | avg_top1=0.7412
#   [train] epoch 56 | batch 600/7127 | avg_loss=0.5802 | avg_top1=0.7342
#   [train] epoch 56 | batch 900/7127 | avg_loss=0.5764 | avg_top1=0.7269
#   [train] epoch 56 | batch 1200/7127 | avg_loss=0.5796 | avg_top1=0.7225
#   [train] epoch 56 | batch 1500/7127 | avg_loss=0.5773 | avg_top1=0.7229
#   [train] epoch 56 | batch 1800/7127 | avg_loss=0.5812 | avg_top1=0.7194
#   [train] epoch 56 | batch 2100/7127 | avg_loss=0.5818 | avg_top1=0.7177
#   [train] epoch 56 | batch 2400/7127 | avg_loss=0.5808 | avg_top1=0.7178
#   [train] epoch 56 | batch 2700/7127 | avg_loss=0.5770 | avg_top1=0.7125
#   [train] epoch 56 | batch 3000/7127 | avg_loss=0.5744 | avg_top1=0.7124
#   [train] epoch 56 | batch 3300/7127 | avg_loss=0.5765 | avg_top1=0.7113
#   [train] epoch 56 | batch 3600/7127 | avg_loss=0.5781 | avg_top1=0.7097
#   [train] epoch 56 | batch 3900/7127 | avg_loss=0.5752 | avg_top1=0.7140
#   [train] epoch 56 | batch 4200/7127 | avg_loss=0.5750 | avg_top1=0.7131
#   [train] epoch 56 | batch 4500/7127 | avg_loss=0.5749 | avg_top1=0.7132
#   [train] epoch 56 | batch 4800/7127 | avg_loss=0.5736 | avg_top1=0.7128
#   [train] epoch 56 | batch 5100/7127 | avg_loss=0.5733 | avg_top1=0.7122
#   [train] epoch 56 | batch 5400/7127 | avg_loss=0.5739 | avg_top1=0.7118
#   [train] epoch 56 | batch 5700/7127 | avg_loss=0.5738 | avg_top1=0.7120
#   [train] epoch 56 | batch 6000/7127 | avg_loss=0.5750 | avg_top1=0.7116
#   [train] epoch 56 | batch 6300/7127 | avg_loss=0.5750 | avg_top1=0.7108
#   [train] epoch 56 | batch 6600/7127 | avg_loss=0.5754 | avg_top1=0.7105
#   [train] epoch 56 | batch 6900/7127 | avg_loss=0.5752 | avg_top1=0.7096
#   [train] epoch 56 | batch 7127/7127 | avg_loss=0.5752 | avg_top1=0.7095
# Epoch 56 | fine-tune | lr=9.06e-08 | train_loss=0.5752, train_acc=0.7095 | val_loss=1.5488, val_acc=0.7643, val_top5=0.9727
#
# --- Starting epoch 57 ---
#   [train] epoch 57 | batch 300/7127 | avg_loss=0.5160 | avg_top1=0.7233
#   [train] epoch 57 | batch 600/7127 | avg_loss=0.5513 | avg_top1=0.7179
#   [train] epoch 57 | batch 900/7127 | avg_loss=0.5538 | avg_top1=0.7151
#   [train] epoch 57 | batch 1200/7127 | avg_loss=0.5672 | avg_top1=0.7168
#   [train] epoch 57 | batch 1500/7127 | avg_loss=0.5695 | avg_top1=0.7097
#   [train] epoch 57 | batch 1800/7127 | avg_loss=0.5722 | avg_top1=0.7031
#   [train] epoch 57 | batch 2100/7127 | avg_loss=0.5720 | avg_top1=0.7057
#   [train] epoch 57 | batch 2400/7127 | avg_loss=0.5697 | avg_top1=0.7061
#   [train] epoch 57 | batch 2700/7127 | avg_loss=0.5730 | avg_top1=0.7057
#   [train] epoch 57 | batch 3000/7127 | avg_loss=0.5756 | avg_top1=0.7049
#   [train] epoch 57 | batch 3300/7127 | avg_loss=0.5762 | avg_top1=0.7048
#   [train] epoch 57 | batch 3600/7127 | avg_loss=0.5743 | avg_top1=0.7077
#   [train] epoch 57 | batch 3900/7127 | avg_loss=0.5746 | avg_top1=0.7074
#   [train] epoch 57 | batch 4200/7127 | avg_loss=0.5735 | avg_top1=0.7057
#   [train] epoch 57 | batch 4500/7127 | avg_loss=0.5726 | avg_top1=0.7066
#   [train] epoch 57 | batch 4800/7127 | avg_loss=0.5726 | avg_top1=0.7083
#   [train] epoch 57 | batch 5100/7127 | avg_loss=0.5727 | avg_top1=0.7091
#   [train] epoch 57 | batch 5400/7127 | avg_loss=0.5740 | avg_top1=0.7081
#   [train] epoch 57 | batch 5700/7127 | avg_loss=0.5739 | avg_top1=0.7089
#   [train] epoch 57 | batch 6000/7127 | avg_loss=0.5742 | avg_top1=0.7101
#   [train] epoch 57 | batch 6300/7127 | avg_loss=0.5725 | avg_top1=0.7103
#   [train] epoch 57 | batch 6600/7127 | avg_loss=0.5736 | avg_top1=0.7093
#   [train] epoch 57 | batch 6900/7127 | avg_loss=0.5728 | avg_top1=0.7091
#   [train] epoch 57 | batch 7127/7127 | avg_loss=0.5738 | avg_top1=0.7088
# Epoch 57 | fine-tune | lr=5.81e-08 | train_loss=0.5738, train_acc=0.7088 | val_loss=1.5503, val_acc=0.7641, val_top5=0.9729
#
# --- Starting epoch 58 ---
#   [train] epoch 58 | batch 300/7127 | avg_loss=0.5776 | avg_top1=0.6913
#   [train] epoch 58 | batch 600/7127 | avg_loss=0.5684 | avg_top1=0.7127
#   [train] epoch 58 | batch 900/7127 | avg_loss=0.5758 | avg_top1=0.7079
#   [train] epoch 58 | batch 1200/7127 | avg_loss=0.5730 | avg_top1=0.7085
#   [train] epoch 58 | batch 1500/7127 | avg_loss=0.5775 | avg_top1=0.7109
#   [train] epoch 58 | batch 1800/7127 | avg_loss=0.5765 | avg_top1=0.7073
#   [train] epoch 58 | batch 2100/7127 | avg_loss=0.5738 | avg_top1=0.7071
#   [train] epoch 58 | batch 2400/7127 | avg_loss=0.5790 | avg_top1=0.7034
#   [train] epoch 58 | batch 2700/7127 | avg_loss=0.5768 | avg_top1=0.7052
#   [train] epoch 58 | batch 3000/7127 | avg_loss=0.5741 | avg_top1=0.7075
#   [train] epoch 58 | batch 3300/7127 | avg_loss=0.5718 | avg_top1=0.7091
#   [train] epoch 58 | batch 3600/7127 | avg_loss=0.5712 | avg_top1=0.7094
#   [train] epoch 58 | batch 3900/7127 | avg_loss=0.5723 | avg_top1=0.7094
#   [train] epoch 58 | batch 4200/7127 | avg_loss=0.5731 | avg_top1=0.7078
#   [train] epoch 58 | batch 4500/7127 | avg_loss=0.5747 | avg_top1=0.7079
#   [train] epoch 58 | batch 4800/7127 | avg_loss=0.5722 | avg_top1=0.7078
#   [train] epoch 58 | batch 5100/7127 | avg_loss=0.5701 | avg_top1=0.7084
#   [train] epoch 58 | batch 5400/7127 | avg_loss=0.5693 | avg_top1=0.7087
#   [train] epoch 58 | batch 5700/7127 | avg_loss=0.5698 | avg_top1=0.7082
#   [train] epoch 58 | batch 6000/7127 | avg_loss=0.5690 | avg_top1=0.7090
#   [train] epoch 58 | batch 6300/7127 | avg_loss=0.5706 | avg_top1=0.7100
#   [train] epoch 58 | batch 6600/7127 | avg_loss=0.5713 | avg_top1=0.7112
#   [train] epoch 58 | batch 6900/7127 | avg_loss=0.5706 | avg_top1=0.7114
#   [train] epoch 58 | batch 7127/7127 | avg_loss=0.5708 | avg_top1=0.7120
# Epoch 58 | fine-tune | lr=3.28e-08 | train_loss=0.5708, train_acc=0.7120 | val_loss=1.5507, val_acc=0.7647, val_top5=0.9726
#
# --- Starting epoch 59 ---
#   [train] epoch 59 | batch 300/7127 | avg_loss=0.5772 | avg_top1=0.7117
#   [train] epoch 59 | batch 600/7127 | avg_loss=0.5614 | avg_top1=0.7240
#   [train] epoch 59 | batch 900/7127 | avg_loss=0.5626 | avg_top1=0.7172
#   [train] epoch 59 | batch 1200/7127 | avg_loss=0.5580 | avg_top1=0.7136
#   [train] epoch 59 | batch 1500/7127 | avg_loss=0.5538 | avg_top1=0.7134
#   [train] epoch 59 | batch 1800/7127 | avg_loss=0.5493 | avg_top1=0.7181
#   [train] epoch 59 | batch 2100/7127 | avg_loss=0.5537 | avg_top1=0.7179
#   [train] epoch 59 | batch 2400/7127 | avg_loss=0.5583 | avg_top1=0.7164
#   [train] epoch 59 | batch 2700/7127 | avg_loss=0.5585 | avg_top1=0.7186
#   [train] epoch 59 | batch 3000/7127 | avg_loss=0.5594 | avg_top1=0.7199
#   [train] epoch 59 | batch 3300/7127 | avg_loss=0.5631 | avg_top1=0.7183
#   [train] epoch 59 | batch 3600/7127 | avg_loss=0.5673 | avg_top1=0.7168
#   [train] epoch 59 | batch 3900/7127 | avg_loss=0.5675 | avg_top1=0.7162
#   [train] epoch 59 | batch 4200/7127 | avg_loss=0.5655 | avg_top1=0.7188
#   [train] epoch 59 | batch 4500/7127 | avg_loss=0.5659 | avg_top1=0.7190
#   [train] epoch 59 | batch 4800/7127 | avg_loss=0.5661 | avg_top1=0.7184
#   [train] epoch 59 | batch 5100/7127 | avg_loss=0.5673 | avg_top1=0.7192
#   [train] epoch 59 | batch 5400/7127 | avg_loss=0.5660 | avg_top1=0.7183
#   [train] epoch 59 | batch 5700/7127 | avg_loss=0.5680 | avg_top1=0.7157
#   [train] epoch 59 | batch 6000/7127 | avg_loss=0.5681 | avg_top1=0.7160
#   [train] epoch 59 | batch 6300/7127 | avg_loss=0.5684 | avg_top1=0.7153
#   [train] epoch 59 | batch 6600/7127 | avg_loss=0.5696 | avg_top1=0.7137
#   [train] epoch 59 | batch 6900/7127 | avg_loss=0.5716 | avg_top1=0.7126
#   [train] epoch 59 | batch 7127/7127 | avg_loss=0.5728 | avg_top1=0.7128
# Epoch 59 | fine-tune | lr=1.46e-08 | train_loss=0.5728, train_acc=0.7128 | val_loss=1.5515, val_acc=0.7648, val_top5=0.9722
#
# --- Starting epoch 60 ---
#   [train] epoch 60 | batch 300/7127 | avg_loss=0.5719 | avg_top1=0.6933
#   [train] epoch 60 | batch 600/7127 | avg_loss=0.5691 | avg_top1=0.7115
#   [train] epoch 60 | batch 900/7127 | avg_loss=0.5730 | avg_top1=0.7015
#   [train] epoch 60 | batch 1200/7127 | avg_loss=0.5702 | avg_top1=0.7043
#   [train] epoch 60 | batch 1500/7127 | avg_loss=0.5760 | avg_top1=0.7108
#   [train] epoch 60 | batch 1800/7127 | avg_loss=0.5759 | avg_top1=0.7070
#   [train] epoch 60 | batch 2100/7127 | avg_loss=0.5750 | avg_top1=0.7104
#   [train] epoch 60 | batch 2400/7127 | avg_loss=0.5716 | avg_top1=0.7129
#   [train] epoch 60 | batch 2700/7127 | avg_loss=0.5726 | avg_top1=0.7139
#   [train] epoch 60 | batch 3000/7127 | avg_loss=0.5758 | avg_top1=0.7144
#   [train] epoch 60 | batch 3300/7127 | avg_loss=0.5756 | avg_top1=0.7124
#   [train] epoch 60 | batch 3600/7127 | avg_loss=0.5752 | avg_top1=0.7132
#   [train] epoch 60 | batch 3900/7127 | avg_loss=0.5722 | avg_top1=0.7125
#   [train] epoch 60 | batch 4200/7127 | avg_loss=0.5724 | avg_top1=0.7145
#   [train] epoch 60 | batch 4500/7127 | avg_loss=0.5716 | avg_top1=0.7135
#   [train] epoch 60 | batch 4800/7127 | avg_loss=0.5728 | avg_top1=0.7130
#   [train] epoch 60 | batch 5100/7127 | avg_loss=0.5725 | avg_top1=0.7125
#   [train] epoch 60 | batch 5400/7127 | avg_loss=0.5730 | avg_top1=0.7110
#   [train] epoch 60 | batch 5700/7127 | avg_loss=0.5722 | avg_top1=0.7111
#   [train] epoch 60 | batch 6000/7127 | avg_loss=0.5721 | avg_top1=0.7109
#   [train] epoch 60 | batch 6300/7127 | avg_loss=0.5722 | avg_top1=0.7111
#   [train] epoch 60 | batch 6600/7127 | avg_loss=0.5716 | avg_top1=0.7105
#   [train] epoch 60 | batch 6900/7127 | avg_loss=0.5706 | avg_top1=0.7105
#   [train] epoch 60 | batch 7127/7127 | avg_loss=0.5712 | avg_top1=0.7102
# Epoch 60 | fine-tune | lr=3.65e-09 | train_loss=0.5712, train_acc=0.7102 | val_loss=1.5520, val_acc=0.7648, val_top5=0.9722
#
# --- Starting epoch 61 ---
#   [train] epoch 61 | batch 300/7127 | avg_loss=0.5641 | avg_top1=0.7254
#   [train] epoch 61 | batch 600/7127 | avg_loss=0.5505 | avg_top1=0.7240
#   [train] epoch 61 | batch 900/7127 | avg_loss=0.5627 | avg_top1=0.7199
#   [train] epoch 61 | batch 1200/7127 | avg_loss=0.5680 | avg_top1=0.7178
#   [train] epoch 61 | batch 1500/7127 | avg_loss=0.5691 | avg_top1=0.7188
#   [train] epoch 61 | batch 1800/7127 | avg_loss=0.5736 | avg_top1=0.7153
#   [train] epoch 61 | batch 2100/7127 | avg_loss=0.5702 | avg_top1=0.7142
#   [train] epoch 61 | batch 2400/7127 | avg_loss=0.5685 | avg_top1=0.7205
#   [train] epoch 61 | batch 2700/7127 | avg_loss=0.5696 | avg_top1=0.7188
#   [train] epoch 61 | batch 3000/7127 | avg_loss=0.5674 | avg_top1=0.7179
#   [train] epoch 61 | batch 3300/7127 | avg_loss=0.5697 | avg_top1=0.7148
#   [train] epoch 61 | batch 3600/7127 | avg_loss=0.5703 | avg_top1=0.7124
#   [train] epoch 61 | batch 3900/7127 | avg_loss=0.5713 | avg_top1=0.7117
#   [train] epoch 61 | batch 4200/7127 | avg_loss=0.5723 | avg_top1=0.7095
#   [train] epoch 61 | batch 4500/7127 | avg_loss=0.5738 | avg_top1=0.7088
#   [train] epoch 61 | batch 4800/7127 | avg_loss=0.5738 | avg_top1=0.7084
#   [train] epoch 61 | batch 5100/7127 | avg_loss=0.5733 | avg_top1=0.7075
#   [train] epoch 61 | batch 5400/7127 | avg_loss=0.5731 | avg_top1=0.7081
#   [train] epoch 61 | batch 5700/7127 | avg_loss=0.5724 | avg_top1=0.7077
#   [train] epoch 61 | batch 6000/7127 | avg_loss=0.5709 | avg_top1=0.7093
#   [train] epoch 61 | batch 6300/7127 | avg_loss=0.5703 | avg_top1=0.7095
#   [train] epoch 61 | batch 6600/7127 | avg_loss=0.5702 | avg_top1=0.7104
#   [train] epoch 61 | batch 6900/7127 | avg_loss=0.5698 | avg_top1=0.7103
#   [train] epoch 61 | batch 7127/7127 | avg_loss=0.5708 | avg_top1=0.7091
# Epoch 61 | fine-tune | lr=0.00e+00 | train_loss=0.5708, train_acc=0.7091 | val_loss=1.5525, val_acc=0.7646, val_top5=0.9722
# Early stopping at epoch 61 (best epoch: 45).
#
# Final evaluation
# Validation -> loss: 1.5272, top1: 0.7653, top5: 0.9758
# Test       -> loss: 1.5683, top1: 0.7584, top5: 0.9721
# Best checkpoint: c:\Users\Thijs\Desktop\Ai Art Critic\models\wikiart_test7_best.pt
# Best epoch: 45
# Best val_top1: 0.7653
# Saved history: c:\Users\Thijs\Desktop\Ai Art Critic\models\results\wikiart_test7_history.csv
# Saved summary: c:\Users\Thijs\Desktop\Ai Art Critic\models\results\wikiart_tests_1_to_7_summary.csv

# %%
print("History rows:", len(history_df))
if len(history_df) > 0:
    best_idx = history_df["val_top1"].idxmax()
    print("\nBest validation row:")
    display(history_df.loc[[best_idx]])

print("\nFinal Validation:", final_val)
print("Final Test:", final_test)

results_dir = Path.cwd() / "models" / "results"
print("\nSaved files:")
print("-", results_dir / "wikiart_test7_history.csv")
print("-", results_dir / "wikiart_tests_1_to_7_summary.csv")
print("-", Path.cwd() / "models" / "wikiart_test7_best.pt")

summary_path = results_dir / "wikiart_tests_1_to_7_summary.csv"
if summary_path.exists():
    display(pd.read_csv(summary_path).tail(3))
# Out:
# History rows: 61
#
# Best validation row:
#     epoch      stage            lr  train_loss  train_top1  train_top5  \
# 44     45  fine-tune  8.638705e-07     0.59712    0.710976    0.952592
#
#     val_loss  val_top1  val_top5
# 44  1.527187   0.76525  0.975845
# Final Validation: {'loss': 1.5271870344596619, 'top1': 0.7652501432948173, 'top5': 0.9758454106280193}
# Final Test: {'loss': 1.5682787281970052, 'top1': 0.7583551769331586, 'top5': 0.9721494102228048}
#
# Saved files:
# - c:\Users\Thijs\Desktop\Ai Art Critic\models\results\wikiart_test7_history.csv
# - c:\Users\Thijs\Desktop\Ai Art Critic\models\results\wikiart_tests_1_to_7_summary.csv
# - c:\Users\Thijs\Desktop\Ai Art Critic\models\wikiart_test7_best.pt
#                                             notebook  exists  \
# 4           wikiart_style_classification_test5.ipynb    True
# 5  wikiart_style_classification_test6_max_accurac...    True
# 6  wikiart_style_classification_test7_max_accurac...    True
#
#                                   model_name  val_loss  val_top1  val_top5  \
# 4                       vit_base_patch16_384  5.637950  0.692986  0.792369
# 5  vit_base_patch16_384.augreg_in21k_ft_in1k  1.888643  0.758536  0.975845
# 6  vit_base_patch16_384.augreg_in21k_ft_in1k  1.527187  0.765250  0.975845
#
#    test_loss  test_top1  test_top5  best_val_top1  best_epoch experiment  \
# 4   3.797295   0.681136   0.777505       0.692986        20.0      test5
# 5   1.926972   0.748689   0.972068       0.758536        24.0      test6
# 6   1.568279   0.758355   0.972149       0.765250        45.0      test7
#
#                        saved_at_utc
# 4  2026-03-12T14:07:50.261156+00:00
# 5  2026-03-16T11:19:13.132687+00:00
# 6  2026-03-19T00:50:52.171441+00:00
